# %% [markdown]
# ## Utiliser l'API de l'ADEME avec Python

# %%
import requests

root_url = 'https://data.ademe.fr/data-fair/api/v1/datasets/dpe03existant/lines'


def quick_requests(params:dict) -> dict:
    response = requests.get(root_url, params=params)
    response.raise_for_status()
    return response.json()

# %% [markdown]
# Effectuer une première requête GET en récupérant les données de la première page. Observer la réponse de la requête.

# %%
params = {
    'page': 1
}

quick_requests(params)
# Out:
# {'total': 12867611,
#  'next': 'https://data.ademe.fr/data-fair/api/v1/datasets/meg-83tjwtg8dyz4vv7h1dqe/lines?after=1362404395025%2C572937',
#  'results': [{'configuration_installation_chauffage_n1': 'Installation de chauffage simple',
#    'conso_chauffage_installation_chauffage_n1': 3506.6,
#    'type_generateur_n1_ecs_n1': 'Réseau de chaleur isolé',
#    'numero_voie_ban': '50',
#    'score_ban': 0.66,
#    'surface_habitable_immeuble': 23551,
#    'conso_auxiliaires_ep': 932.1,
#    'deperditions_murs': 14.2,
#    'cout_eclairage': 17.6,
#    'conso_auxiliaires_ef': 405.2,
#    'statut_geocodage': "adresse géocodée ban à l'adresse",
#    'ventilation_posterieure_2012': 0,
#    'cout_chauffage': 276,
#    'conso_5_usages_par_m2_ep': 257,
#    'date_etablissement_dpe': '2022-02-07',
#    'conso_ecs_ef_energie_n1': 3670.8,
#    'conso_ecs_ef_energie_n2': 0,
#    'emission_ges_chauffage': 550.5,
#    'description_installation_chauffage_n1': 'Réseau de chaleur vertueux isolé (système collectif). Emetteur(s): radiateur bitube sans robinet thermostatique',
#    'conso_5_usages_par_m2_ef': 238,
#    'cout_ecs_energie_n2': 0,
#    'conso_chauffage_ef_energie_n1': 3506.6,
#    'conso_chauffage_ef_energie_n2': 0,
#    'qualite_isolation_menuiseries': 'insuffisante',
#    'cout_total_5_usages_energie_n2': 112.6,
#    'date_reception_dpe': '2022-02-08',
#    'cout_total_5_usages_energie_n1': 564.9,
#    'cout_ecs_energie_n1': 288.9,
#    'qualite_isolation_plancher_bas': 'très bonne',
#    'modele_dpe': 'DPE 3CL 2021 méthode logement',
#    'qualite_isolation_enveloppe': 'insuffisante',
#    'conso_chauffage_generateur_n1_installation_n1': 3506.6,
#    'type_energie_n1': 'Réseau de Chauffage urbain',
#    'emission_ges_eclairage': 4.2,
#    'type_energie_n2': 'Électricité',
#    'code_postal_ban': '75013',
#    'emission_ges_ecs': 576.3,
#    'conso_5_usages_ef_energie_n2': 465.8,
#    'conso_5_usages_ef': 7643.1,
#    'conso_5_usages_ef_energie_n1': 7177.4,
#    'code_insee_ban': '75113',
#    'deperditions_planchers_bas': 0,
#    'conso_5_usages_ep': 8248.7,
#    'date_fin_validite_dpe': '2032-02-06',
#    'deperditions_enveloppe': 66.3,
#    'code_region_ban': '11',
#    'volume_stockage_generateur_n1_ecs_n1': 0,
#    'surface_chauffee_installation_chauffage_n1': 32,
#    'version_dpe': 2.1,
#    'besoin_ecs': 925,
#    'coordonnee_cartographique_x_ban': 653293.35,
#    'type_generateur_chauffage_principal': 'Réseau de chaleur isolé',
#    'type_energie_principale_ecs': 'Réseau de Chauffage urbain',
#    'apport_solaire_saison_chauffe': 1229663.1,
#    'adresse_ban': '50 Rue du Disque 75013 Paris',
#    'nombre_appartement': 1,
#    'deperditions_renouvellement_air': 9.2,
#    '_rand': 77079,
#    'surface_habitable_desservie_par_installation_ecs_n1': 32,
#    'production_electricite_pv_kwhep_par_an': 0,
#    'type_installation_chauffage': 'collectif',
#    'nombre_niveau_logement': 1,
#    'surface_habitable_logement': 32,
#    'cout_ecs': 288.9,
#    'type_installation_ecs_n1': 'installation collective',
#    'emission_ges_5_usages_energie_n1': 1126.8,
#    'emission_ges_5_usages_energie_n2': 30.1,
#    'apport_interne_saison_froide': 0,
#    'emission_ges_5_usages_par_m2': 36,
#    'description_generateur_chauffage_n1_installation_n1': 'Réseau de chaleur isolé',
#    'qualite_isolation_plancher_haut_comble_perdu': 'très bonne',
#    'apport_interne_saison_chauffe': 1231780.6,
#    'apport_solaire_saison_froide': 0,
#    'type_generateur_n1_installation_n1': 'Réseau de chaleur isolé',
#    'nombre_logements_desservis_par_installation_ecs_n1': 1,
#    'complement_adresse_logement': 'Etage 10',
#    'cout_auxiliaires': 95,
#    'type_emetteur_installation_chauffage_n1': 'Radiateur bitube sans robinet thermostatique sur réseau collectif eau chaude haute température(sup ou egal 65°C)',
#    'besoin_chauffage': 2313.7,
#    'configuration_installation_ecs_n1': "Un seul système d'ECS sans solaire",
#    'description_installation_ecs_n1': 'Combiné au système de chauffage',
#    'classe_inertie_batiment': 'Légère',
#    'deperditions_ponts_thermiques': 6.2,
#    'type_generateur_chauffage_principal_ecs': 'Réseau de chaleur isolé',
#    'emission_ges_refroidissement': 0,
#    'hauteur_sous_plafond': 2.5,
#    'conso_chauffage_ef': 3506.6,
#    'nom_commune_ban': 'Paris',
#    'annee_construction': 1948,
#    '_geopoint': '48.82458102161721,2.363825947937033',
#    'date_visite_diagnostiqueur': '2022-02-02',
#    'type_batiment': 'appartement',
#    'periode_construction': '1948-1974',
#    'type_installation_ecs': 'collectif',
#    'conso_ecs_ep': 3670.8,
#    'conso_ecs_ef': 3670.8,
#    'emission_ges_5_usages': 1157,
#    'date_derniere_modification_dpe': '2024-06-25',
#    'etiquette_ges': 'D',
#    'identifiant_ban': '75113_2804_00050',
#    'deperditions_baies_vitrees': 36.7,
#    'type_energie_generateur_n1_ecs_n1': 'Réseau de Chauffage urbain',
#    'ubat_w_par_m2_k': 4.05,
#    'numero_etage_appartement': 0,
#    'nom_commune_brut': 'PARIS 13',
#    'conso_ef_installation_ecs_n1': 3670.8,
#    'etiquette_dpe': 'D',
#    'description_generateur_n1_ecs_n1': 'Réseau de chaleur isolé',
#    'code_departement_ban': '75',
#    'type_installation_chauffage_n1': 'installation collective',
#    'methode_application_dpe': 'dpe appartement individuel',
#    'adresse_brut': '50 rue du disque',
#    'cout_total_5_usages': 677.4,
#    'categorie_enr': 'réseau de chaleur ou de froid vertueux',
#    'conso_refroidissement_ef': 0,
#    'conso_eclairage_ef': 60.5,
#    'deperditions_planchers_hauts': 0,
#    'zone_climatique': 'H1a',
#    'conso_ef_generateur_n1_ecs_n1': 3670.8,
#    'emission_ges_ecs_energie_n1': 576.3,
#    'emission_ges_ecs_energie_n2': 0,
#    'cout_refroidissement': 0,
#    'conso_chauffage_ep': 3506.6,
#    'conso_eclairage_ep': 139.2,
#    'usage_generateur_n1_installation_n1': 'chauffage + ecs',
#    'nom_rue_ban': 'Rue du Disque',
#    'qualite_isolation_murs': 'insuffisante',
#    'type_installation_solaire_n1': 'Non affecté',
#    'classe_altitude': 'inférieur à 400m',
#    'conso_refroidissement_ep': 0,
#    'type_energie_principale_chauffage': 'Réseau de Chauffage urbain',
#    'numero_dpe': '2275E0252200Y',
#    '_i': 1362404395002,
#    'besoin_refroidissement': 0,
#    'emission_ges_chauffage_energie_n2': 0,
#    'emission_ges_chauffage_energie_n1': 550.5,
#    'cout_chauffage_energie_n2': 0,
#    'deperditions_portes': 0,
#    'cout_chauffage_energie_n1': 276,
#    'coordonnee_cartographique_y_ban': 6858468.14,
#    'type_energie_generateur_n1_installation_n1': 'Réseau de Chauffage urbain',
#    'code_postal_brut': 75013,
#    'emission_ges_auxiliaires': 25.9,
#    'usage_generateur_n1_ecs_n1': 'chauffage + ecs',
#    '_score': None,
#    '_id': '159d721651064eddc5f26d764e7e2cebfc755a8137bb10a6ec484de5a00328b0'},
#   {'configuration_installation_chauffage_n1': 'Installation de chauffage simple',
#    'conso_chauffage_installation_chauffage_n1': 7114.5,
#    'type_generateur_n1_ecs_n1': 'Ballon électrique à accumulation vertical Catégorie B ou 2 étoiles',
#    'numero_voie_ban': '12',
#    'score_ban': 0.45,
#    'conso_auxiliaires_ep': 1355.1,
#    'deperditions_murs': 55.2,
#    'cout_eclairage': 22.5,
#    'conso_auxiliaires_ef': 589.2,
#    'statut_geocodage': "adresse géocodée ban à l'adresse",
#    'ventilation_posterieure_2012': 0,
#    'cout_chauffage': 1186.5,
#    'conso_5_usages_par_m2_ep': 309,
#    'date_etablissement_dpe': '2022-04-24',
#    'conso_ecs_ef_energie_n1': 2139.2,
#    'emission_ges_chauffage': 562,
#    'description_installation_chauffage_n1': 'Radiateur électrique à inertie (modélisé comme un radiateur à accumulation) (système individuel)',
#    'conso_5_usages_par_m2_ef': 134,
#    'conso_chauffage_ef_energie_n1': 7114.5,
#    'presence_brasseur_air': 0,
#    'qualite_isolation_menuiseries': 'bonne',
#    'date_reception_dpe': '2022-04-25',
#    'cout_total_5_usages_energie_n1': 1664,
#    'cout_ecs_energie_n1': 356.7,
#    'qualite_isolation_plancher_bas': 'insuffisante',
#    'isolation_toiture': 0,
#    'modele_dpe': 'DPE 3CL 2021 méthode logement',
#    'qualite_isolation_enveloppe': 'insuffisante',
#    'conso_chauffage_generateur_n1_installation_n1': 7114.5,
#    'type_energie_n1': 'Électricité',
#    'emission_ges_eclairage': 9.3,
#    'code_postal_ban': '54160',
#    'emission_ges_ecs': 139,
#    'conso_5_usages_ef': 9978,
#    'conso_5_usages_ef_energie_n1': 9978,
#    'code_insee_ban': '54437',
#    'deperditions_planchers_bas': 17.8,
#    'conso_5_usages_ep': 22949.4,
#    'date_fin_validite_dpe': '2032-04-23',
#    'deperditions_enveloppe': 172.3,
#    'code_region_ban': '44',
#    'volume_stockage_generateur_n1_ecs_n1': 200,
#    'surface_chauffee_installation_chauffage_n1': 74.2,
#    'version_dpe': 2.1,
#    'besoin_ecs': 1330.2,
#    'coordonnee_cartographique_x_ban': 931875.41,
#    'type_generateur_chauffage_principal': 'Radiateur électrique à accumulation',
#    'type_energie_principale_ecs': 'Électricité',
#    'apport_solaire_saison_chauffe': 1303711.6,
#    'adresse_ban': '12 Rue de la Rouotte 54160 Pulligny',
#    'nombre_appartement': 1,
#    'deperditions_renouvellement_air': 55.2,
#    '_rand': 134784,
#    'surface_habitable_desservie_par_installation_ecs_n1': 74.2,
#    'production_electricite_pv_kwhep_par_an': 0,
#    'type_installation_chauffage': 'individuel',
#    'nombre_niveau_logement': 2,
#    'surface_habitable_logement': 74.2,
#    'cout_ecs': 356.7,
#    'type_installation_ecs_n1': 'installation individuelle',
#    'emission_ges_5_usages_energie_n1': 748.1,
#    'apport_interne_saison_froide': 0,
#    'emission_ges_5_usages_par_m2': 10,
#    'description_generateur_chauffage_n1_installation_n1': 'Electrique - Radiateur électrique à inertie (modélisé comme un radiateur à accumulation)',
#    'qualite_isolation_plancher_haut_comble_perdu': 'très bonne',
#    'apport_interne_saison_chauffe': 2207566.9,
#    'apport_solaire_saison_froide': 0,
#    'type_generateur_n1_installation_n1': 'Radiateur électrique à accumulation',
#    'nombre_logements_desservis_par_installation_ecs_n1': 1,
#    'cout_auxiliaires': 98.3,
#    'type_emetteur_installation_chauffage_n1': 'Radiateur électrique à accumulation',
#    'besoin_chauffage': 7083.4,
#    'configuration_installation_ecs_n1': "Un seul système d'ECS sans solaire",
#    'description_installation_ecs_n1': 'Ballon électrique à accumulation vertical (catégorie B ou 2 étoiles), contenance ballon 200 L',
#    'classe_inertie_batiment': 'Moyenne',
#    'deperditions_ponts_thermiques': 17.6,
#    'type_generateur_chauffage_principal_ecs': 'Ballon électrique à accumulation vertical Catégorie B ou 2 étoiles',
#    'emission_ges_refroidissement': 0,
#    'hauteur_sous_plafond': 2.5,
#    'conso_chauffage_ef': 7114.5,
#    'nom_commune_ban': 'Pulligny',
#    'annee_construction': 1947,
#    '_geopoint': '48.542561039861354,6.142095069599721',
#    'date_visite_diagnostiqueur': '2022-04-24',
#    'type_batiment': 'appartement',
#    'periode_construction': 'avant 1948',
#    'type_installation_ecs': 'individuel',
#    'conso_ecs_ep': 4920.1,
#    'protection_solaire_exterieure': 1,
#    'conso_ecs_ef': 2139.2,
#    'emission_ges_5_usages': 748.1,
#    'date_derniere_modification_dpe': '2025-01-20',
#    'etiquette_ges': 'B',
#    'identifiant_ban': '54437_0420_00012',
#    'deperditions_baies_vitrees': 23.7,
#    'type_energie_generateur_n1_ecs_n1': 'Électricité',
#    'ubat_w_par_m2_k': 0.95,
#    'numero_etage_appartement': 0,
#    'nom_commune_brut': 'PULLIGNY',
#    'conso_ef_installation_ecs_n1': 2139.2,
#    'etiquette_dpe': 'E',
#    'description_generateur_n1_ecs_n1': 'Electrique - Ballon électrique à accumulation vertical (catégorie B ou 2 étoiles)',
#    'code_departement_ban': '54',
#    'type_installation_chauffage_n1': 'installation individuelle',
#    'methode_application_dpe': 'dpe appartement individuel',
#    'adresse_brut': '12 rue de la Rouotte',
#    'logement_traversant': 1,
#    'cout_total_5_usages': 1664,
#    'conso_refroidissement_ef': 0,
#    'conso_eclairage_ef': 135.1,
#    'deperditions_planchers_hauts': 0,
#    'zone_climatique': 'H1b',
#    'conso_ef_generateur_n1_ecs_n1': 2139.2,
#    'emission_ges_ecs_energie_n1': 139,
#    'cout_refroidissement': 0,
#    'conso_chauffage_ep': 16363.4,
#    'conso_eclairage_ep': 310.8,
#    'usage_generateur_n1_installation_n1': 'chauffage',
#    'nom_rue_ban': 'Rue de la Rouotte',
#    'qualite_isolation_murs': 'insuffisante',
#    'type_installation_solaire_n1': 'Non affecté',
#    'classe_altitude': 'inférieur à 400m',
#    'conso_refroidissement_ep': 0,
#    'type_energie_principale_chauffage': 'Électricité',
#    'numero_dpe': '2254E0866216D',
#    '_i': 1362404395007,
#    'besoin_refroidissement': 0,
#    'indicateur_confort_ete': 'moyen',
#    'emission_ges_chauffage_energie_n1': 562,
#    'inertie_lourde': 0,
#    'deperditions_portes': 2.9,
#    'cout_chauffage_energie_n1': 1186.5,
#    'coordonnee_cartographique_y_ban': 6831539.51,
#    'type_energie_generateur_n1_installation_n1': 'Électricité',
#    'code_postal_brut': 54160,
#    'emission_ges_auxiliaires': 37.7,
#    'usage_generateur_n1_ecs_n1': 'ecs',
#    '_score': None,
#    '_id': 'fa9c94f157de461027b028ae133e3936e7c290dc6b6be421f12faf6742a9944d'},
#   {'configuration_installation_chauffage_n1': 'Installation de chauffage simple',
#    'conso_chauffage_installation_chauffage_n1': 6044.4,
#    'type_generateur_n1_ecs_n1': 'Chaudière gaz à condensation 2001-2015',
#    'numero_voie_ban': '74',
#    'score_ban': 0.8,
#    'conso_auxiliaires_ep': 506.3,
#    'deperditions_murs': 35.5,
#    'cout_eclairage': 21,
#    'conso_auxiliaires_ef': 14,
#    'statut_geocodage': 'adresse non géocodée ban car aucune correspondance trouvée',
#    'ventilation_posterieure_2012': 0,
#    'cout_chauffage': 576,
#    'conso_5_usages_par_m2_ep': 216.6,
#    'date_etablissement_dpe': '2022-06-06',
#    'conso_ecs_ef_energie_n1': 1631.8,
#    'conso_ecs_ef_energie_n2': 0,
#    'emission_ges_chauffage': 12.4,
#    'description_installation_chauffage_n1': 'Installation de chauffage seul classique',
#    'conso_5_usages_par_m2_ef': 206.7,
#    'cout_ecs_energie_n2': 0,
#    'conso_chauffage_ef_energie_n1': 6044.4,
#    'conso_chauffage_ef_energie_n2': 0,
#    'presence_brasseur_air': 0,
#    'qualite_isolation_menuiseries': 'moyenne',
#    'cout_total_5_usages_energie_n2': 21,
#    'date_reception_dpe': '2022-06-07',
#    'cout_total_5_usages_energie_n1': 731,
#    'cout_ecs_energie_n1': 155,
#    'qualite_isolation_plancher_bas': 'très bonne',
#    'isolation_toiture': 0,
#    'modele_dpe': 'DPE 3CL 2021 méthode logement',
#    'qualite_isolation_enveloppe': 'insuffisante',
#    'conso_chauffage_generateur_n1_installation_n1': 6044.4,
#    'type_energie_n1': 'Gaz naturel',
#    'emission_ges_eclairage': 0.1,
#    'type_energie_n2': 'Électricité',
#    'code_postal_ban': '75007',
#    'emission_ges_ecs': 3.3,
#    'conso_5_usages_ef_energie_n2': 72.9,
#    'conso_5_usages_ef': 7969.2,
#    'conso_5_usages_ef_energie_n1': 7676.2,
#    'code_insee_ban': '75107',
#    'deperditions_planchers_bas': 0,
#    'conso_5_usages_ep': 8350.1,
#    'date_fin_validite_dpe': '2032-06-05',
#    'deperditions_enveloppe': 108,
#    'code_region_ban': '11',
#    'volume_stockage_generateur_n1_ecs_n1': 10,
#    'surface_chauffee_installation_chauffage_n1': 38.6,
#    'version_dpe': 2.1,
#    'besoin_ecs': 1005.1,
#    'coordonnee_cartographique_x_ban': 649991.77,
#    'type_generateur_chauffage_principal': 'Chaudière gaz à condensation 2001-2015',
#    'type_energie_principale_ecs': 'Gaz naturel',
#    'apport_solaire_saison_chauffe': 583379.3,
#    'adresse_ban': '74 Rue de Sèvres 75007 Paris',
#    'deperditions_renouvellement_air': 36,
#    '_rand': 947741,
#    'surface_habitable_desservie_par_installation_ecs_n1': 38.6,
#    'production_electricite_pv_kwhep_par_an': 0,
#    'type_installation_chauffage': 'individuel',
#    'nombre_niveau_logement': 1,
#    'surface_habitable_logement': 38.6,
#    'cout_ecs': 155,
#    'type_installation_ecs_n1': 'installation individuelle',
#    'emission_ges_5_usages_energie_n1': 15.7,
#    'emission_ges_5_usages_energie_n2': 0.1,
#    'apport_interne_saison_froide': 0,
#    'emission_ges_5_usages_par_m2': 45.7,
#    'description_generateur_chauffage_n1_installation_n1': 'Générateur 1',
#    'apport_interne_saison_chauffe': 1414780.1,
#    'apport_solaire_saison_froide': 0,
#    'type_generateur_n1_installation_n1': 'Chaudière gaz à condensation 2001-2015',
#    'nombre_logements_desservis_par_installation_ecs_n1': 1,
#    'cout_auxiliaires': 816,
#    'type_emetteur_installation_chauffage_n1': 'Radiateur monotube avec robinet thermostatique sur réseau individuel eau chaude basse ou moyenne température(inf 65°C)',
#    'besoin_chauffage': 4735.9,
#    'configuration_installation_ecs_n1': "Un seul système d'ECS sans solaire",
#    'description_installation_ecs_n1': 'Installation ECS 1',
#    'classe_inertie_batiment': 'Moyenne',
#    'deperditions_ponts_thermiques': 10.4,
#    'type_generateur_chauffage_principal_ecs': 'Chaudière gaz à condensation 2001-2015',
#    'emission_ges_refroidissement': 0,
#    'hauteur_sous_plafond': 2.8,
#    'conso_chauffage_ef': 6044.4,
#    'nom_commune_ban': 'Paris',
#    'annee_construction': 1948,
#    '_geopoint': '48.84762702994544,2.318554043655058',
#    'date_visite_diagnostiqueur': '2022-06-06',
#    'type_batiment': 'appartement',
#    'periode_construction': 'avant 1948',
#    'type_installation_ecs': 'individuel',
#    'conso_ecs_ep': 1631.8,
#    'protection_solaire_exterieure': 0,
#    'conso_ecs_ef': 1631.8,
#    'emission_ges_5_usages': 1761.7,
#    'date_derniere_modification_dpe': '2024-06-25',
#    'etiquette_ges': 'D',
#    'identifiant_ban': '75107_8955_00074',
#    'deperditions_baies_vitrees': 20.2,
#    'type_energie_generateur_n1_ecs_n1': 'Gaz naturel',
#    'ubat_w_par_m2_k': 0.62,
#    'nom_commune_brut': 'PARIS 07',
#    'conso_ef_installation_ecs_n1': 1631.8,
#    'etiquette_dpe': 'D',
#    'description_generateur_n1_ecs_n1': 'Générateur 1',
#    'code_departement_ban': '75',
#    'type_installation_chauffage_n1': 'installation individuelle',
#    'methode_application_dpe': 'dpe appartement individuel',
#    'adresse_brut': '74 RUE DE SEVRES',
#    'logement_traversant': 0,
#    'cout_total_5_usages': 816,
#    'conso_refroidissement_ef': 0,
#    'conso_eclairage_ef': 72.9,
#    'deperditions_planchers_hauts': 0,
#    'zone_climatique': 'H1a',
#    'conso_ef_generateur_n1_ecs_n1': 1631.8,
#    'emission_ges_ecs_energie_n1': 3.3,
#    'emission_ges_ecs_energie_n2': 0,
#    'cout_refroidissement': 0,
#    'conso_chauffage_ep': 6044.4,
#    'conso_eclairage_ep': 167.6,
#    'usage_generateur_n1_installation_n1': 'chauffage + ecs',
#    'nom_rue_ban': 'Rue de Sèvres',
#    'qualite_isolation_murs': 'insuffisante',
#    'type_installation_solaire_n1': 'Non affecté',
#    'classe_altitude': 'inférieur à 400m',
#    'conso_refroidissement_ep': 0,
#    'type_energie_principale_chauffage': 'Gaz naturel',
#    'numero_dpe': '2275E1242094U',
#    '_i': 1362404395010,
#    'besoin_refroidissement': 0,
#    'emission_ges_chauffage_energie_n2': 0,
#    'indicateur_confort_ete': 'insuffisant',
#    'emission_ges_chauffage_energie_n1': 12.4,
#    'inertie_lourde': 0,
#    'cout_chauffage_energie_n2': 0,
#    'deperditions_portes': 5.9,
#    'cout_chauffage_energie_n1': 576,
#    'coordonnee_cartographique_y_ban': 6861058.33,
#    'type_energie_generateur_n1_installation_n1': 'Gaz naturel',
#    'code_postal_brut': 75007,
#    'emission_ges_auxiliaires': 0.5,
#    'usage_generateur_n1_ecs_n1': 'chauffage + ecs',
#    '_score': None,
#    '_id': '4a14f5b0016d8086c445c6abe2743608fd23ae5e6e56fbd91e6fa29a4a443842'},
#   {'configuration_installation_chauffage_n2': 'Installation de chauffage simple',
#    'configuration_installation_chauffage_n1': 'Installation de chauffage simple',
#    'conso_chauffage_installation_chauffage_n1': 1849.2,
#    'type_generateur_n1_ecs_n1': 'Ballon électrique à accumulation vertical Catégorie B ou 2 étoiles',
#    'numero_voie_ban': '28',
#    'score_ban': 0.54,
#    'conso_chauffage_generateur_n1_installation_n2': 856.1,
#    'conso_auxiliaires_ep': 1309.6,
#    'conso_chauffage_installation_chauffage_n2': 856.1,
#    'deperditions_murs': 35,
#    'cout_eclairage': 19.1,
#    'conso_auxiliaires_ef': 569.4,
#    'statut_geocodage': "adresse géocodée ban à l'adresse",
#    'ventilation_posterieure_2012': 0,
#    'cout_chauffage': 609.1,
#    'conso_5_usages_par_m2_ep': 238,
#    'date_etablissement_dpe': '2022-06-29',
#    'conso_ecs_ef_energie_n1': 1735.9,
#    'emission_ges_chauffage': 277.8,
#    'description_installation_chauffage_n2': 'Radiateur électrique NFC, NF** et NF*** avec programmateur pièce par pièce (système individuel)',
#    'description_installation_chauffage_n1': 'Panneau rayonnant électrique NFC, NF** et NF*** avec programmateur pièce par pièce (système individuel)',
#    'qualite_isolation_plancher_haut_comble_amenage': 'bonne',
#    'conso_5_usages_par_m2_ef': 103,
#    'conso_chauffage_ef_energie_n1': 3517,
#    'presence_brasseur_air': 0,
#    'qualite_isolation_menuiseries': 'très bonne',
#    'date_reception_dpe': '2022-06-30',
#    'cout_total_5_usages_energie_n1': 1027.5,
#    'cout_ecs_energie_n1': 300.7,
#    'qualite_isolation_plancher_bas': 'insuffisante',
#    'isolation_toiture': 1,
#    'modele_dpe': 'DPE 3CL 2021 méthode logement',
#    'qualite_isolation_enveloppe': 'bonne',
#    'conso_chauffage_generateur_n1_installation_n1': 1849.2,
#    'type_energie_n1': 'Électricité',
#    'emission_ges_eclairage': 7.6,
#    'code_postal_ban': '44390',
#    'emission_ges_ecs': 112.8,
#    'conso_5_usages_ef': 5932.8,
#    'conso_5_usages_ef_energie_n1': 5932.8,
#    'code_insee_ban': '44205',
#    'deperditions_planchers_bas': 4.2,
#    'conso_5_usages_ep': 13645.4,
#    'date_fin_validite_dpe': '2032-06-28',
#    'deperditions_enveloppe': 117.3,
#    'complement_adresse_batiment': '2022.06.29.774.BONNOT.GSM',
#    'code_region_ban': '52',
#    'volume_stockage_generateur_n1_ecs_n1': 200,
#    'surface_chauffee_installation_chauffage_n2': 14,
#    'surface_chauffee_installation_chauffage_n1': 30.2,
#    'version_dpe': 2.1,
#    'besoin_ecs': 955.2,
#    'coordonnee_cartographique_x_ban': 366351.8,
#    'type_generateur_chauffage_principal': 'Panneau rayonnant électrique NFC, NF** et NF***',
#    'type_energie_principale_ecs': 'Électricité',
#    'apport_solaire_saison_chauffe': 766239.5,
#    'adresse_ban': '28 Rue du Calvaire 44390 Les Touches',
#    'deperditions_renouvellement_air': 47.5,
#    '_rand': 507481,
#    'surface_habitable_desservie_par_installation_ecs_n1': 57.2,
#    'production_electricite_pv_kwhep_par_an': 0,
#    'nombre_niveau_logement': 3,
#    'surface_habitable_logement': 57.2,
#    'cout_ecs': 300.7,
#    'type_installation_ecs_n1': 'installation individuelle',
#    'emission_ges_5_usages_energie_n1': 434.7,
#    'apport_interne_saison_froide': 0,
#    'emission_ges_5_usages_par_m2': 7,
#    'description_generateur_chauffage_n1_installation_n1': 'Electrique - Panneau rayonnant électrique NFC, NF** et NF***',
#    'apport_interne_saison_chauffe': 1733663.2,
#    'apport_solaire_saison_froide': 0,
#    'type_generateur_n1_installation_n1': 'Panneau rayonnant électrique NFC, NF** et NF***',
#    'nombre_logements_desservis_par_installation_ecs_n1': 1,
#    'type_generateur_n1_installation_n2': 'radiateur électrique NFC, NF** et NF***',
#    'cout_auxiliaires': 98.6,
#    'type_emetteur_installation_chauffage_n2': 'radiateur électrique NFC, NF** et NF***',
#    'type_emetteur_installation_chauffage_n1': 'Panneau rayonnant NFC, NF** et NF***',
#    'besoin_chauffage': 4317.6,
#    'configuration_installation_ecs_n1': "Un seul système d'ECS sans solaire",
#    'description_installation_ecs_n1': 'Ballon électrique à accumulation vertical (catégorie B ou 2 étoiles), contenance ballon 200 L',
#    'description_generateur_chauffage_n1_installation_n2': 'Electrique - Radiateur électrique NFC, NF** et NF***',
#    'classe_inertie_batiment': 'Légère',
#    'deperditions_ponts_thermiques': 10.6,
#    'type_generateur_chauffage_principal_ecs': 'Ballon électrique à accumulation vertical Catégorie B ou 2 étoiles',
#    'emission_ges_refroidissement': 0,
#    'hauteur_sous_plafond': 2.3,
#    'conso_chauffage_ef': 3517,
#    'nom_commune_ban': 'Les Touches',
#    '_geopoint': '47.44197201939978,-1.4294339847987738',
#    'date_visite_diagnostiqueur': '2022-06-28',
#    'type_batiment': 'maison',
#    'periode_construction': 'avant 1948',
#    'conso_ecs_ep': 3992.6,
#    'protection_solaire_exterieure': 1,
#    'conso_ecs_ef': 1735.9,
#    'emission_ges_5_usages': 434.7,
#    'date_derniere_modification_dpe': '2024-02-06',
#    'etiquette_ges': 'B',
#    'identifiant_ban': '44205_0077_00028',
#    'deperditions_baies_vitrees': 10,
#    'type_energie_generateur_n1_ecs_n1': 'Électricité',
#    'ubat_w_par_m2_k': 0.62,
#    'numero_etage_appartement': 0,
#    'nom_commune_brut': 'LES TOUCHES',
#    'conso_ef_installation_ecs_n1': 1735.9,
#    'etiquette_dpe': 'D',
#    'description_generateur_n1_ecs_n1': 'Electrique - Ballon électrique à accumulation vertical (catégorie B ou 2 étoiles)',
#    'code_departement_ban': '44',
#    'type_installation_chauffage_n1': 'installation individuelle',
#    'type_installation_chauffage_n2': 'installation individuelle',
#    'methode_application_dpe': 'dpe maison individuelle',
#    'adresse_brut': '28 rue du Calvaire',
#    'logement_traversant': 0,
#    'cout_total_5_usages': 1027.5,
#    'conso_refroidissement_ef': 0,
#    'conso_eclairage_ef': 110.4,
#    'deperditions_planchers_hauts': 9.9,
#    'zone_climatique': 'H2b',
#    'conso_ef_generateur_n1_ecs_n1': 1735.9,
#    'emission_ges_ecs_energie_n1': 112.8,
#    'cout_refroidissement': 0,
#    'conso_chauffage_ep': 8089.2,
#    'usage_generateur_n1_installation_n2': 'chauffage',
#    'conso_eclairage_ep': 254,
#    'usage_generateur_n1_installation_n1': 'chauffage',
#    'nom_rue_ban': 'Rue du Calvaire',
#    'qualite_isolation_murs': 'insuffisante',
#    'type_installation_solaire_n1': 'Non affecté',
#    'classe_altitude': 'inférieur à 400m',
#    'conso_refroidissement_ep': 0,
#    'type_energie_principale_chauffage': 'Électricité',
#    'numero_dpe': '2244E1489464V',
#    '_i': 1362404395011,
#    'besoin_refroidissement': 0,
#    'indicateur_confort_ete': 'moyen',
#    'emission_ges_chauffage_energie_n1': 277.8,
#    'inertie_lourde': 0,
#    'deperditions_portes': 0,
#    'cout_chauffage_energie_n1': 609.1,
#    'type_energie_generateur_n1_installation_n2': 'Électricité',
#    'coordonnee_cartographique_y_ban': 6713984.87,
#    'type_energie_generateur_n1_installation_n1': 'Électricité',
#    'code_postal_brut': 44390,
#    'emission_ges_auxiliaires': 36.4,
#    'usage_generateur_n1_ecs_n1': 'ecs',
#    '_score': None,
#    '_id': '90d9f9976dab9f96ee60407ff7e8c6b0f0c3bc8db6d5b5d1bdfe5d99e5efaf25'},
#   {'configuration_installation_chauffage_n1': 'Installation de chauffage simple',
#    'conso_chauffage_installation_chauffage_n1': 1972.8,
#    'type_generateur_n1_ecs_n1': 'Ballon électrique à accumulation vertical Autres ou inconnue',
#    'numero_voie_ban': '41',
#    'score_ban': 0.68,
#    'conso_auxiliaires_ep': 214.4,
#    'deperditions_murs': 27.1,
#    'cout_eclairage': 11.3,
#    'conso_auxiliaires_ef': 93.2,
#    'statut_geocodage': "adresse géocodée ban à l'adresse",
#    'ventilation_posterieure_2012': 0,
#    'cout_chauffage': 365.5,
#    'conso_5_usages_par_m2_ep': 259,
#    'date_etablissement_dpe': '2022-02-01',
#    'conso_ecs_ef_energie_n1': 1513,
#    'emission_ges_chauffage': 155.9,
#    'description_installation_chauffage_n1': 'Panneau rayonnant électrique NFC, NF** et NF*** avec programmateur pièce par pièce (système individuel)',
#    'conso_5_usages_par_m2_ef': 112,
#    'conso_chauffage_ef_energie_n1': 1972.8,
#    'qualite_isolation_menuiseries': 'moyenne',
#    'date_reception_dpe': '2022-02-02',
#    'cout_total_5_usages_energie_n1': 674.4,
#    'cout_ecs_energie_n1': 280.3,
#    'qualite_isolation_plancher_bas': 'très bonne',
#    'modele_dpe': 'DPE 3CL 2021 méthode logement',
#    'qualite_isolation_enveloppe': 'insuffisante',
#    'conso_chauffage_generateur_n1_installation_n1': 1972.8,
#    'type_energie_n1': 'Électricité',
#    'emission_ges_eclairage': 4.2,
#    'code_postal_ban': '93370',
#    'emission_ges_ecs': 98.3,
#    'conso_5_usages_ef': 3639.9,
#    'conso_5_usages_ef_energie_n1': 3639.9,
#    'code_insee_ban': '93047',
#    'deperditions_planchers_bas': 0,
#    'conso_5_usages_ep': 8371.7,
#    'date_fin_validite_dpe': '2032-01-31',
#    'deperditions_enveloppe': 58.6,
#    'code_region_ban': '11',
#    'volume_stockage_generateur_n1_ecs_n1': 100,
#    'surface_chauffee_installation_chauffage_n1': 32.2,
#    'version_dpe': 2.1,
#    'besoin_ecs': 927.6,
#    'coordonnee_cartographique_x_ban': 668284.8,
#    'type_generateur_chauffage_principal': 'Panneau rayonnant électrique NFC, NF** et NF***',
#    'type_energie_principale_ecs': 'Électricité',
#    'apport_solaire_saison_chauffe': 325568.4,
#    'adresse_ban': '41 Rue Henri Barbusse 93370 Montfermeil',
#    'nombre_appartement': 1,
#    'deperditions_renouvellement_air': 15,
#    '_rand': 361733,
#    'surface_habitable_desservie_par_installation_ecs_n1': 32.2,
#    'production_electricite_pv_kwhep_par_an': 0,
#    'type_installation_chauffage': 'individuel',
#    'nombre_niveau_logement': 1,
#    'surface_habitable_logement': 32.2,
#    'cout_ecs': 280.3,
#    'type_installation_ecs_n1': 'installation individuelle',
#    'emission_ges_5_usages_energie_n1': 264.4,
#    'apport_interne_saison_froide': 0,
#    'emission_ges_5_usages_par_m2': 8,
#    'description_generateur_chauffage_n1_installation_n1': 'Electrique - Panneau rayonnant électrique NFC, NF** et NF***',
#    'qualite_isolation_plancher_haut_comble_perdu': 'très bonne',
#    'apport_interne_saison_chauffe': 1237674.8,
#    'apport_solaire_saison_froide': 0,
#    'type_generateur_n1_installation_n1': 'Panneau rayonnant électrique NFC, NF** et NF***',
#    'nombre_logements_desservis_par_installation_ecs_n1': 1,
#    'complement_adresse_logement': '1er étage',
#    'cout_auxiliaires': 17.3,
#    'type_emetteur_installation_chauffage_n1': 'Panneau rayonnant NFC, NF** et NF***',
#    'besoin_chauffage': 2142.6,
#    'configuration_installation_ecs_n1': "Un seul système d'ECS sans solaire",
#    'description_installation_ecs_n1': 'Ballon électrique à accumulation vertical (autres catégorie ou inconnue), contenance ballon 100 L',
#    'classe_inertie_batiment': 'Légère',
#    'deperditions_ponts_thermiques': 5,
#    'type_generateur_chauffage_principal_ecs': 'Ballon électrique à accumulation vertical Autres ou inconnue',
#    'emission_ges_refroidissement': 0,
#    'hauteur_sous_plafond': 2.5,
#    'conso_chauffage_ef': 1972.8,
#    'nom_commune_ban': 'Montfermeil',
#    'annee_construction': 1947,
#    '_geopoint': '48.90032396404854,2.567392985729962',
#    'date_visite_diagnostiqueur': '2022-01-31',
#    'type_batiment': 'appartement',
#    'periode_construction': 'avant 1948',
#    'type_installation_ecs': 'individuel',
#    'conso_ecs_ep': 3479.8,
#    'conso_ecs_ef': 1513,
#    'emission_ges_5_usages': 264.4,
#    'date_derniere_modification_dpe': '2024-06-25',
#    'etiquette_ges': 'B',
#    'identifiant_ban': '93047_0760_00041',
#    'deperditions_baies_vitrees': 8.6,
#    'type_energie_generateur_n1_ecs_n1': 'Électricité',
#    'ubat_w_par_m2_k': 1.24,
#    'numero_etage_appartement': 0,
#    'nom_commune_brut': 'MONTFERMEIL',
#    'conso_ef_installation_ecs_n1': 1513,
#    'etiquette_dpe': 'D',
#    'description_generateur_n1_ecs_n1': 'Electrique - Ballon électrique à accumulation vertical (autres catégorie ou inconnue)',
#    'code_departement_ban': '93',
#    'type_installation_chauffage_n1': 'installation individuelle',
#    'methode_application_dpe': 'dpe appartement individuel',
#    'adresse_brut': '41 RUE HENRI BARBUSSE',
#    'cout_total_5_usages': 674.4,
#    'conso_refroidissement_ef': 0,
#    'conso_eclairage_ef': 60.9,
#    'deperditions_planchers_hauts': 0,
#    'zone_climatique': 'H1a',
#    'conso_ef_generateur_n1_ecs_n1': 1513,
#    'emission_ges_ecs_energie_n1': 98.3,
#    'cout_refroidissement': 0,
#    'conso_chauffage_ep': 4537.4,
#    'conso_eclairage_ep': 140.1,
#    'usage_generateur_n1_installation_n1': 'chauffage',
#    'nom_rue_ban': 'Rue Henri Barbusse',
#    'qualite_isolation_murs': 'insuffisante',
#    'type_installation_solaire_n1': 'Non affecté',
#    'classe_altitude': 'inférieur à 400m',
#    'conso_refroidissement_ep': 0,
#    'type_energie_principale_chauffage': 'Électricité',
#    'numero_dpe': '2293E0210795D',
#    '_i': 1362404395012,
#    'besoin_refroidissement': 0,
#    'emission_ges_chauffage_energie_n1': 155.9,
#    'deperditions_portes': 2.9,
#    'cout_chauffage_energie_n1': 365.5,
#    'coordonnee_cartographique_y_ban': 6866789.15,
#    'type_energie_generateur_n1_installation_n1': 'Électricité',
#    'code_postal_brut': 93370,
#    'emission_ges_auxiliaires': 6,
#    'usage_generateur_n1_ecs_n1': 'ecs',
#    '_score': None,
#    '_id': 'edac99464b1a4d046c0c70328942aa915630ab1df9b2d0b255f3d1ea5c02cc02'},
#   {'configuration_installation_chauffage_n2': 'Installation de chauffage simple',
#    'configuration_installation_chauffage_n1': 'Installation de chauffage simple',
#    'conso_chauffage_installation_chauffage_n1': 619.8,
#    'type_generateur_n1_ecs_n1': 'Ballon électrique à accumulation vertical Autres ou inconnue',
#    'numero_voie_ban': '21ter',
#    'score_ban': 0.63,
#    'conso_chauffage_generateur_n1_installation_n2': 557.7,
#    'conso_auxiliaires_ep': 434.4,
#    'conso_chauffage_installation_chauffage_n2': 557.7,
#    'deperditions_murs': 14.8,
#    'cout_eclairage': 14.4,
#    'conso_auxiliaires_ef': 188.9,
#    'statut_geocodage': "adresse géocodée ban à l'adresse",
#    'ventilation_posterieure_2012': 0,
#    'cout_chauffage': 227.2,
#    'conso_5_usages_par_m2_ep': 180,
#    'date_etablissement_dpe': '2022-03-28',
#    'conso_ecs_ef_energie_n1': 1523.7,
#    'emission_ges_chauffage': 93,
#    'description_installation_chauffage_n2': 'Panneau rayonnant électrique NFC, NF** et NF*** avec programmateur sans réduit (système individuel)',
#    'description_installation_chauffage_n1': 'Convecteur électrique NFC, NF** et NF*** avec programmateur sans réduit (système individuel)',
#    'conso_5_usages_par_m2_ef': 78,
#    'conso_chauffage_ef_energie_n1': 1177.6,
#    'presence_brasseur_air': 0,
#    'qualite_isolation_menuiseries': 'moyenne',
#    'date_reception_dpe': '2022-03-29',
#    'cout_total_5_usages_energie_n1': 571.9,
#    'cout_ecs_energie_n1': 293.9,
#    'qualite_isolation_plancher_bas': 'très bonne',
#    'isolation_toiture': 1,
#    'modele_dpe': 'DPE 3CL 2021 méthode logement',
#    'qualite_isolation_enveloppe': 'bonne',
#    'conso_chauffage_generateur_n1_installation_n1': 619.8,
#    'type_energie_n1': 'Électricité',
#    'emission_ges_eclairage': 5.1,
#    'code_postal_ban': '32000',
#    'emission_ges_ecs': 99,
#    'conso_5_usages_ef': 2964.7,
#    'conso_5_usages_ef_energie_n1': 2964.7,
#    'code_insee_ban': '32013',
#    'deperditions_planchers_bas': 0,
#    'conso_5_usages_ep': 6818.9,
#    'date_fin_validite_dpe': '2032-03-27',
#    'deperditions_enveloppe': 58,
#    'code_region_ban': '76',
#    'volume_stockage_generateur_n1_ecs_n1': 150,
#    'surface_chauffee_installation_chauffage_n2': 18.1,
#    'surface_chauffee_installation_chauffage_n1': 19.7,
#    'version_dpe': 2.1,
#    'besoin_ecs': 900.2,
#    'coordonnee_cartographique_x_ban': 506264.58,
#    'type_generateur_chauffage_principal': 'Convecteur électrique NFC, NF** et NF***',
#    'type_energie_principale_ecs': 'Électricité',
#    'apport_solaire_saison_chauffe': 700538.3,
#    'adresse_ban': '21ter Avenue Sambre et Meuse 32000 Auch',
#    'nombre_appartement': 1,
#    'deperditions_renouvellement_air': 17.1,
#    '_rand': 51646,
#    'surface_habitable_desservie_par_installation_ecs_n1': 37.8,
#    'production_electricite_pv_kwhep_par_an': 0,
#    'type_installation_chauffage': 'individuel',
#    'nombre_niveau_logement': 1,
#    'surface_habitable_logement': 37.8,
#    'cout_ecs': 293.9,
#    'type_installation_ecs_n1': 'installation individuelle',
#    'emission_ges_5_usages_energie_n1': 209.3,
#    'apport_interne_saison_froide': 0,
#    'emission_ges_5_usages_par_m2': 5,
#    'description_generateur_chauffage_n1_installation_n1': 'Electrique - Convecteur électrique NFC, NF** et NF***',
#    'qualite_isolation_plancher_haut_comble_perdu': 'moyenne',
#    'apport_interne_saison_chauffe': 1200022.3,
#    'apport_solaire_saison_froide': 0,
#    'type_generateur_n1_installation_n1': 'Convecteur électrique NFC, NF** et NF***',
#    'nombre_logements_desservis_par_installation_ecs_n1': 1,
#    'complement_adresse_logement': 'Etage 2; Porte 117',
#    'type_generateur_n1_installation_n2': 'Panneau rayonnant électrique NFC, NF** et NF***',
#    'cout_auxiliaires': 36.4,
#    'type_emetteur_installation_chauffage_n2': 'Panneau rayonnant NFC, NF** et NF***',
#    'type_emetteur_installation_chauffage_n1': 'Convecteur électrique NFC, NF** et NF***',
#    'besoin_chauffage': 1208.2,
#    'configuration_installation_ecs_n1': "Un seul système d'ECS sans solaire",
#    'description_installation_ecs_n1': 'Ballon électrique à accumulation vertical (autres catégorie ou inconnue), contenance ballon 150 L',
#    'description_generateur_chauffage_n1_installation_n2': 'Electrique - Panneau rayonnant électrique NFC, NF** et NF***',
#    'classe_inertie_batiment': 'Lourde',
#    'deperditions_ponts_thermiques': 8,
#    'type_generateur_chauffage_principal_ecs': 'Ballon électrique à accumulation vertical Autres ou inconnue',
#    'emission_ges_refroidissement': 0,
#    'hauteur_sous_plafond': 2.5,
#    'conso_chauffage_ef': 1177.6,
#    'nom_commune_ban': 'Auch',
#    'annee_construction': 2006,
#    '_geopoint': '43.64785200616111,0.5989960026510905',
#    'date_visite_diagnostiqueur': '2022-03-28',
#    'type_batiment': 'appartement',
#    'periode_construction': '2006-2012',
#    'type_installation_ecs': 'individuel',
#    'conso_ecs_ep': 3504.5,
#    'protection_solaire_exterieure': 1,
#    'conso_ecs_ef': 1523.7,
#    'emission_ges_5_usages': 209.3,
#    'date_derniere_modification_dpe': '2024-06-25',
#    'etiquette_ges': 'A',
#    'identifiant_ban': '32013_4120_00021_ter',
#    'deperditions_baies_vitrees': 10.6,
#    'type_energie_generateur_n1_ecs_n1': 'Électricité',
#    'ubat_w_par_m2_k': 0.52,
#    'numero_etage_appartement': 0,
#    'nom_commune_brut': 'AUCH',
#    'conso_ef_installation_ecs_n1': 1523.7,
#    'etiquette_dpe': 'C',
#    'description_generateur_n1_ecs_n1': 'Electrique - Ballon électrique à accumulation vertical (autres catégorie ou inconnue)',
#    'code_departement_ban': '32',
#    'type_installation_chauffage_n1': 'installation individuelle',
#    'type_installation_chauffage_n2': 'installation individuelle',
#    'methode_application_dpe': 'dpe appartement individuel',
#    'adresse_brut': '21 TER AVENUE SAMBRE ET MEUSE',
#    'logement_traversant': 0,
#    'cout_total_5_usages': 571.9,
#    'conso_refroidissement_ef': 0,
#    'conso_eclairage_ef': 74.6,
#    'deperditions_planchers_hauts': 6,
#    'zone_climatique': 'H2c',
#    'conso_ef_generateur_n1_ecs_n1': 1523.7,
#    'emission_ges_ecs_energie_n1': 99,
#    'cout_refroidissement': 0,
#    'conso_chauffage_ep': 2708.4,
#    'usage_generateur_n1_installation_n2': 'chauffage',
#    'conso_eclairage_ep': 171.5,
#    'usage_generateur_n1_installation_n1': 'chauffage',
#    'nom_rue_ban': 'Avenue Sambre et Meuse',
#    'qualite_isolation_murs': 'insuffisante',
#    'type_installation_solaire_n1': 'Non affecté',
#    'classe_altitude': 'inférieur à 400m',
#    'conso_refroidissement_ep': 0,
#    'type_energie_principale_chauffage': 'Électricité',
#    'numero_dpe': '2232E0641223S',
#    '_i': 1362404395013,
#    'besoin_refroidissement': 0,
#    'indicateur_confort_ete': 'moyen',
#    'emission_ges_chauffage_energie_n1': 93,
#    'inertie_lourde': 1,
#    'deperditions_portes': 1.3,
#    'cout_chauffage_energie_n1': 227.2,
#    'type_energie_generateur_n1_installation_n2': 'Électricité',
#    'coordonnee_cartographique_y_ban': 6286146.68,
#    'type_energie_generateur_n1_installation_n1': 'Électricité',
#    'code_postal_brut': 32000,
#    'emission_ges_auxiliaires': 12.1,
#    'usage_generateur_n1_ecs_n1': 'ecs',
#    '_score': None,
#    '_id': '97bc8839c7b113b3b60b0af1fa48e8cca8679c793c8adfa5390631839e1a9ddd'},
#   {'configuration_installation_chauffage_n1': 'Installation de chauffage simple',
#    'conso_chauffage_installation_chauffage_n1': 13141.9,
#    'type_generateur_n1_ecs_n1': 'Chaudière fioul à condensation 1996-2015',
#    'score_ban': 0.43,
#    'conso_auxiliaires_ep': 1692.8,
#    'deperditions_murs': 55.7,
#    'cout_eclairage': 64.7,
#    'conso_auxiliaires_ef': 736,
#    'statut_geocodage': "adresse géocodée ban à l'adresse",
#    'ventilation_posterieure_2012': 0,
#    'cout_chauffage': 1201.4,
#    'conso_5_usages_par_m2_ep': 154,
#    'date_etablissement_dpe': '2022-02-15',
#    'conso_ecs_ef_energie_n1': 3141.1,
#    'conso_ecs_ef_energie_n2': 0,
#    'emission_ges_chauffage': 4258,
#    'description_installation_chauffage_n1': 'Chaudière individuelle fioul à condensation installée entre 1996 et 2015. Emetteur(s): radiateur bitube avec robinet thermostatique',
#    'qualite_isolation_plancher_haut_comble_amenage': 'bonne',
#    'conso_5_usages_par_m2_ef': 143,
#    'cout_ecs_energie_n2': 0,
#    'conso_chauffage_ef_energie_n1': 13141.9,
#    'conso_chauffage_ef_energie_n2': 0,
#    'qualite_isolation_menuiseries': 'insuffisante',
#    'cout_total_5_usages_energie_n2': 278.2,
#    'date_reception_dpe': '2022-02-16',
#    'cout_total_5_usages_energie_n1': 1488.6,
#    'cout_ecs_energie_n1': 287.2,
#    'qualite_isolation_plancher_bas': 'insuffisante',
#    'modele_dpe': 'DPE 3CL 2021 méthode logement',
#    'qualite_isolation_enveloppe': 'moyenne',
#    'conso_chauffage_generateur_n1_installation_n1': 13141.9,
#    'type_energie_n1': 'Fioul domestique',
#    'emission_ges_eclairage': 15.4,
#    'type_energie_n2': 'Électricité',
#    'code_postal_ban': '71420',
#    'emission_ges_ecs': 1017.7,
#    'conso_5_usages_ef_energie_n2': 959.2,
#    'conso_5_usages_ef': 17242.2,
#    'conso_5_usages_ef_energie_n1': 16283,
#    'code_insee_ban': '71132',
#    'deperditions_planchers_bas': 30.4,
#    'conso_5_usages_ep': 18489.1,
#    'date_fin_validite_dpe': '2032-02-14',
#    'deperditions_enveloppe': 257.6,
#    'code_region_ban': '27',
#    'volume_stockage_generateur_n1_ecs_n1': 120,
#    'surface_chauffee_installation_chauffage_n1': 120,
#    'version_dpe': 2,
#    'besoin_ecs': 1366.7,
#    'coordonnee_cartographique_x_ban': 797336.12,
#    'type_generateur_chauffage_principal': 'Chaudière fioul à condensation 1996-2015',
#    'type_energie_principale_ecs': 'Fioul domestique',
#    'apport_solaire_saison_chauffe': 2214114.3,
#    'adresse_ban': 'Route de Valteuse 71420 Ciry-le-Noble',
#    'deperditions_renouvellement_air': 73.5,
#    '_rand': 293941,
#    'surface_habitable_desservie_par_installation_ecs_n1': 120,
#    'production_electricite_pv_kwhep_par_an': 0,
#    'nombre_niveau_logement': 1,
#    'surface_habitable_logement': 120,
#    'cout_ecs': 287.2,
#    'type_installation_ecs_n1': 'installation individuelle',
#    'emission_ges_5_usages_energie_n1': 5275.7,
#    'emission_ges_5_usages_energie_n2': 62.5,
#    'apport_interne_saison_froide': 0,
#    'emission_ges_5_usages_par_m2': 44,
#    'description_generateur_chauffage_n1_installation_n1': 'Fioul - Chaudière fioul à condensation installée entre 1996 et 2015',
#    'apport_interne_saison_chauffe': 2698410.9,
#    'apport_solaire_saison_froide': 0,
#    'type_generateur_n1_installation_n1': 'Chaudière fioul à condensation 1996-2015',
#    'nombre_logements_desservis_par_installation_ecs_n1': 1,
#    'cout_auxiliaires': 213.5,
#    'type_emetteur_installation_chauffage_n1': 'Radiateur bitube avec robinet thermostatique sur réseau individuel eau chaude haute température(sup ou egal 65°C)',
#    'besoin_chauffage': 9544.3,
#    'configuration_installation_ecs_n1': "Un seul système d'ECS sans solaire",
#    'description_installation_ecs_n1': 'Combiné au système de chauffage, contenance ballon 120 L',
#    'classe_inertie_batiment': 'Très lourde',
#    'deperditions_ponts_thermiques': 42.3,
#    'type_generateur_chauffage_principal_ecs': 'Chaudière fioul à condensation 1996-2015',
#    'emission_ges_refroidissement': 0,
#    'hauteur_sous_plafond': 2.6,
#    'conso_chauffage_ef': 13141.9,
#    'nom_commune_ban': 'Ciry-le-Noble',
#    'annee_construction': 1947,
#    '_geopoint': '46.60422397559692,4.271705006166855',
#    'date_visite_diagnostiqueur': '2021-10-13',
#    'type_batiment': 'maison',
#    'periode_construction': 'avant 1948',
#    'conso_ecs_ep': 3141.1,
#    'conso_ecs_ef': 3141.1,
#    'emission_ges_5_usages': 5338.2,
#    'date_derniere_modification_dpe': '2024-02-06',
#    'etiquette_ges': 'D',
#    'identifiant_ban': '71132_2o14dc',
#    'deperditions_baies_vitrees': 39,
#    'type_energie_generateur_n1_ecs_n1': 'Fioul domestique',
#    'ubat_w_par_m2_k': 0.77,
#    'numero_etage_appartement': 0,
#    'nom_commune_brut': 'CIRY-LE-NOBLE',
#    'conso_ef_installation_ecs_n1': 3141.1,
#    'etiquette_dpe': 'D',
#    'description_generateur_n1_ecs_n1': 'Fioul - Chaudière fioul à condensation installée entre 1996 et 2015',
#    'code_departement_ban': '71',
#    'type_installation_chauffage_n1': 'installation individuelle',
#    'methode_application_dpe': 'dpe maison individuelle',
#    'adresse_brut': 'LA VALTEUSE',
#    'cout_total_5_usages': 1766.8,
#    'conso_refroidissement_ef': 0,
#    'conso_eclairage_ef': 223.2,
#    'deperditions_planchers_hauts': 13.9,
#    'zone_climatique': 'H1c',
#    'conso_ef_generateur_n1_ecs_n1': 3141.1,
#    'emission_ges_ecs_energie_n1': 1017.7,
#    'emission_ges_ecs_energie_n2': 0,
#    'cout_refroidissement': 0,
#    'conso_chauffage_ep': 13141.9,
#    'conso_eclairage_ep': 513.3,
#    'usage_generateur_n1_installation_n1': 'chauffage + ecs',
#    'qualite_isolation_murs': 'insuffisante',
#    'type_installation_solaire_n1': 'Non affecté',
#    'classe_altitude': 'inférieur à 400m',
#    'conso_refroidissement_ep': 0,
#    'type_energie_principale_chauffage': 'Fioul domestique',
#    'numero_dpe': '2271E0312368Y',
#    '_i': 1362404395017,
#    'besoin_refroidissement': 0,
#    'emission_ges_chauffage_energie_n2': 0,
#    'emission_ges_chauffage_energie_n1': 4258,
#    'cout_chauffage_energie_n2': 0,
#    'deperditions_portes': 2.9,
#    'cout_chauffage_energie_n1': 1201.4,
#    'coordonnee_cartographique_y_ban': 6612358.59,
#    'type_energie_generateur_n1_installation_n1': 'Fioul domestique',
#    'code_postal_brut': 71420,
#    'emission_ges_auxiliaires': 47.1,
#    'usage_generateur_n1_ecs_n1': 'chauffage + ecs',
#    '_score': None,
#    '_id': '4e8ba6a62421e9f789dd83687a24fd67009b7568e267d303c10381f41f018620'},
#   {'configuration_installation_chauffage_n1': 'Installation de chauffage simple',
#    'conso_chauffage_installation_chauffage_n1': 3040.9,
#    'type_generateur_n1_ecs_n1': 'Ballon électrique à accumulation vertical Catégorie B ou 2 étoiles',
#    'numero_voie_ban': '9',
#    'score_ban': 0.58,
#    'conso_auxiliaires_ep': 0,
#    'deperditions_murs': 27.1,
#    'cout_eclairage': 10.7,
#    'conso_auxiliaires_ef': 0,
#    'statut_geocodage': "adresse géocodée ban à l'adresse",
#    'ventilation_posterieure_2012': 0,
#    'cout_chauffage': 540.8,
#    'conso_5_usages_par_m2_ep': 326,
#    'date_etablissement_dpe': '2022-02-24',
#    'conso_ecs_ef_energie_n1': 1579.4,
#    'emission_ges_chauffage': 240.2,
#    'description_installation_chauffage_n1': 'Radiateur électrique à inertie (modélisé comme un radiateur à accumulation) avec programmateur pièce par pièce (système individuel)',
#    'conso_5_usages_par_m2_ef': 141,
#    'conso_chauffage_ef_energie_n1': 3040.9,
#    'qualite_isolation_menuiseries': 'moyenne',
#    'date_reception_dpe': '2022-02-25',
#    'cout_total_5_usages_energie_n1': 832.3,
#    'cout_ecs_energie_n1': 280.9,
#    'qualite_isolation_plancher_bas': 'très bonne',
#    'modele_dpe': 'DPE 3CL 2021 méthode logement',
#    'qualite_isolation_enveloppe': 'insuffisante',
#    'conso_chauffage_generateur_n1_installation_n1': 3040.9,
#    'type_energie_n1': 'Électricité',
#    'emission_ges_eclairage': 4.1,
#    'code_postal_ban': '89000',
#    'emission_ges_ecs': 102.7,
#    'conso_5_usages_ef': 4680.4,
#    'conso_5_usages_ef_energie_n1': 4680.4,
#    'code_insee_ban': '89024',
#    'deperditions_planchers_bas': 0,
#    'conso_5_usages_ep': 10764.9,
#    'date_fin_validite_dpe': '2032-02-23',
#    'deperditions_enveloppe': 89.1,
#    'code_region_ban': '27',
#    'volume_stockage_generateur_n1_ecs_n1': 100,
#    'surface_chauffee_installation_chauffage_n1': 33,
#    'version_dpe': 2.1,
#    'besoin_ecs': 949.9,
#    'coordonnee_cartographique_x_ban': 742960.97,
#    'type_generateur_chauffage_principal': 'Radiateur électrique à accumulation',
#    'type_energie_principale_ecs': 'Électricité',
#    'apport_solaire_saison_chauffe': 1045520.1,
#    'adresse_ban': '9 Rue de la Marine 89000 Auxerre',
#    'nombre_appartement': 1,
#    'deperditions_renouvellement_air': 36.2,
#    '_rand': 429496,
#    'surface_habitable_desservie_par_installation_ecs_n1': 33,
#    'production_electricite_pv_kwhep_par_an': 0,
#    'type_installation_chauffage': 'individuel',
#    'nombre_niveau_logement': 1,
#    'surface_habitable_logement': 33,
#    'cout_ecs': 280.9,
# ...
#    'categorie_enr': 'chauffage au bois',
#    'conso_refroidissement_ef': 0,
#    'conso_eclairage_ef': 217.4,
#    'deperditions_planchers_hauts': 92.5,
#    'zone_climatique': 'H2a',
#    'conso_ef_generateur_n1_ecs_n1': 3730,
#    'emission_ges_ecs_energie_n1': 1208.5,
#    'emission_ges_ecs_energie_n2': 0,
#    'emission_ges_ecs_energie_n3': 0,
#    'cout_refroidissement': 0,
#    'conso_chauffage_ep': 28030.5,
#    'usage_generateur_n1_installation_n2': 'chauffage',
#    'conso_eclairage_ep': 499.9,
#    'usage_generateur_n1_installation_n1': 'chauffage + ecs',
#    'qualite_isolation_murs': 'insuffisante',
#    'type_installation_solaire_n1': 'Non affecté',
#    'classe_altitude': 'inférieur à 400m',
#    'conso_refroidissement_ep': 0,
#    'type_energie_principale_chauffage': 'Fioul domestique',
#    'numero_dpe': '2256E0388464D',
#    '_i': 1362404395023,
#    'emission_ges_chauffage_energie_n3': 0,
#    'besoin_refroidissement': 0,
#    'emission_ges_chauffage_energie_n2': 407.5,
#    'emission_ges_chauffage_energie_n1': 4681.1,
#    'cout_chauffage_energie_n2': 434.8,
#    'deperditions_portes': 14.9,
#    'cout_chauffage_energie_n1': 1320.8,
#    'cout_chauffage_energie_n3': 0,
#    'type_energie_generateur_n1_installation_n2': 'Bois – Bûches',
#    'coordonnee_cartographique_y_ban': 6723089.29,
#    'type_energie_generateur_n1_installation_n1': 'Fioul domestique',
#    'code_postal_brut': 56760,
#    'emission_ges_auxiliaires': 52.3,
#    'usage_generateur_n1_ecs_n1': 'chauffage + ecs',
#    '_score': None,
#    '_id': '2f006f14a1734db42551beaa96c7a5f7fcc880bb4f6dba5068cc250442179185'},
#   {'configuration_installation_chauffage_n1': 'Installation de chauffage avec insert ou poêle bois en appoint',
#    'conso_chauffage_installation_chauffage_n1': 9654.7,
#    'type_generateur_n1_ecs_n1': 'chauffe-eau électrique instantané',
#    'score_ban': 0.95,
#    'conso_auxiliaires_ep': 1007.4,
#    'deperditions_murs': 37,
#    'cout_eclairage': 24,
#    'conso_auxiliaires_ef': 438,
#    'statut_geocodage': "adresse géocodée ban à l'adresse",
#    'ventilation_posterieure_2012': 0,
#    'cout_chauffage': 1114,
#    'conso_5_usages_par_m2_ep': 284.6,
#    'date_etablissement_dpe': '2022-05-23',
#    'conso_ecs_ef_energie_n1': 1441.3,
#    'conso_ecs_ef_energie_n2': 0,
#    'emission_ges_chauffage': 576.7,
#    'description_installation_chauffage_n1': 'Installation de chauffage avec insert ou poêle bois ou biomasse en appoint',
#    'description_generateur_chauffage_n2_installation_n1': 'Poêle/insert bois bûches (sans label flamme verte)',
#    'conso_5_usages_par_m2_ef': 151.6,
#    'cout_ecs_energie_n2': 0,
#    'conso_chauffage_ef_energie_n1': 5858.6,
#    'conso_chauffage_ef_energie_n2': 3796.2,
#    'presence_brasseur_air': 0,
#    'qualite_isolation_menuiseries': 'moyenne',
#    'cout_total_5_usages_energie_n2': 121.5,
#    'date_reception_dpe': '2022-05-29',
#    'cout_total_5_usages_energie_n1': 1631.8,
#    'cout_ecs_energie_n1': 459.5,
#    'isolation_toiture': 1,
#    'usage_generateur_n2_installation_n1': 'chauffage',
#    'modele_dpe': 'DPE 3CL 2021 méthode logement',
#    'qualite_isolation_enveloppe': 'moyenne',
#    'conso_chauffage_generateur_n1_installation_n1': 5858.6,
#    'type_energie_n1': 'Électricité',
#    'emission_ges_eclairage': 9.7,
#    'type_energie_n2': 'Bois – Bûches',
#    'code_postal_ban': '68570',
#    'emission_ges_ecs': 93.7,
#    'conso_5_usages_ef_energie_n2': 3796.2,
#    'conso_5_usages_ef': 11674.2,
#    'conso_5_usages_ef_energie_n1': 7878,
#    'code_insee_ban': '68318',
#    'deperditions_planchers_bas': 19.2,
#    'conso_5_usages_ep': 21915.6,
#    'date_fin_validite_dpe': '2032-05-22',
#    'deperditions_enveloppe': 169.5,
#    'code_region_ban': '44',
#    'type_generateur_n2_installation_n1': 'insert installé à partir de 2005 sans label flamme verte',
#    'type_energie_generateur_n2_installation_n1': 'Bois – Bûches',
#    'volume_stockage_generateur_n1_ecs_n1': 200,
#    'surface_chauffee_installation_chauffage_n1': 77,
#    'version_dpe': 2.1,
#    'besoin_ecs': 1196.3,
#    'coordonnee_cartographique_x_ban': 1015890.5,
#    'type_generateur_chauffage_principal': 'Autres émetteurs à effet joule',
#    'type_energie_principale_ecs': 'Électricité',
#    'apport_solaire_saison_chauffe': 3149572.7,
#    'adresse_ban': 'Chemin Haulweg 68570 Soultzmatt',
#    'deperditions_renouvellement_air': 61.4,
#    '_rand': 372170,
#    'surface_habitable_desservie_par_installation_ecs_n1': 77,
#    'production_electricite_pv_kwhep_par_an': 0,
#    'nombre_niveau_logement': 1,
#    'surface_habitable_logement': 77,
#    'cout_ecs': 244,
#    'type_installation_ecs_n1': 'installation individuelle',
#    'emission_ges_5_usages_energie_n1': 594.2,
#    'emission_ges_5_usages_energie_n2': 113.9,
#    'apport_interne_saison_froide': 0,
#    'emission_ges_5_usages_par_m2': 9.1,
#    'description_generateur_chauffage_n1_installation_n1': 'Générateur à effet joule direct',
#    'apport_interne_saison_chauffe': 2182996.7,
#    'apport_solaire_saison_froide': 0,
#    'type_generateur_n1_installation_n1': 'Autres émetteurs à effet joule',
#    'nombre_logements_desservis_par_installation_ecs_n1': 1,
#    'cout_auxiliaires': 74,
#    'type_emetteur_installation_chauffage_n1': 'Poêle charbon',
#    'besoin_chauffage': 9450.2,
#    'configuration_installation_ecs_n1': "Un seul système d'ECS sans solaire",
#    'description_installation_ecs_n1': 'Système ECS',
#    'classe_inertie_batiment': 'Moyenne',
#    'deperditions_ponts_thermiques': 55.5,
#    'type_generateur_chauffage_principal_ecs': 'chauffe-eau électrique instantané',
#    'emission_ges_refroidissement': 0,
#    'hauteur_sous_plafond': 2.5,
#    'conso_chauffage_ef': 9654.7,
#    'nom_commune_ban': 'Soultzmatt',
#    'annee_construction': 1995,
#    '_geopoint': '47.963173257450535,7.234704359032687',
#    'date_visite_diagnostiqueur': '2022-05-28',
#    'type_batiment': 'maison',
#    'periode_construction': '1989-2000',
#    'conso_ecs_ep': 3314.9,
#    'protection_solaire_exterieure': 0,
#    'conso_ecs_ef': 1441.3,
#    'emission_ges_5_usages': 708.4,
#    'date_derniere_modification_dpe': '2024-02-06',
#    'etiquette_ges': 'B',
#    'identifiant_ban': '68318_0305',
#    'deperditions_baies_vitrees': 46.8,
#    'type_energie_generateur_n1_ecs_n1': 'Électricité',
#    'date_installation_generateur_n1_ecs_n1': 'Avant 2010',
#    'ubat_w_par_m2_k': 0.85,
#    'nom_commune_brut': 'Soultzmatt',
#    'conso_ef_installation_ecs_n1': 1441.3,
#    'etiquette_dpe': 'E',
#    'description_generateur_n1_ecs_n1': 'Chauffe-eau électrique',
#    'code_departement_ban': '68',
#    'type_installation_chauffage_n1': 'installation individuelle',
#    'methode_application_dpe': 'dpe maison individuelle',
#    'adresse_brut': 'Chemin Haulweg',
#    'logement_traversant': 1,
#    'cout_total_5_usages': 1455,
#    'conso_refroidissement_ef': 0,
#    'conso_eclairage_ef': 140.2,
#    'deperditions_planchers_hauts': 7.8,
#    'zone_climatique': 'H1b',
#    'conso_ef_generateur_n1_ecs_n1': 1441.3,
#    'emission_ges_ecs_energie_n1': 93.7,
#    'emission_ges_ecs_energie_n2': 0,
#    'cout_refroidissement': 0,
#    'conso_chauffage_ep': 17270.9,
#    'conso_eclairage_ep': 322.4,
#    'usage_generateur_n1_installation_n1': 'chauffage',
#    'qualite_isolation_murs': 'moyenne',
#    'type_installation_solaire_n1': 'Non affecté',
#    'classe_altitude': 'inférieur à 400m',
#    'conso_refroidissement_ep': 0,
#    'type_energie_principale_chauffage': 'Électricité',
#    'numero_dpe': '2268E1169752D',
#    '_i': 1362404395024,
#    'besoin_refroidissement': 0,
#    'emission_ges_chauffage_energie_n2': 113.9,
#    'indicateur_confort_ete': 'moyen',
#    'emission_ges_chauffage_energie_n1': 462.8,
#    'inertie_lourde': 0,
#    'cout_chauffage_energie_n2': 121.5,
#    'deperditions_portes': 3.2,
#    'cout_chauffage_energie_n1': 1294,
#    'conso_chauffage_generateur_n2_installation_n1': 3796.2,
#    'coordonnee_cartographique_y_ban': 6771004,
#    'type_energie_generateur_n1_installation_n1': 'Électricité',
#    'code_postal_brut': 68570,
#    'emission_ges_auxiliaires': 28,
#    'usage_generateur_n1_ecs_n1': 'ecs',
#    '_score': None,
#    '_id': 'cd1c587e728a4d01d8713bdd57f435aed1299d77c14562036a35d950c6571a7b'},
#   {'configuration_installation_chauffage_n2': 'Installation de chauffage simple',
#    'configuration_installation_chauffage_n1': 'Installation de chauffage avec insert ou poêle bois en appoint',
#    'conso_chauffage_installation_chauffage_n1': 3404.4,
#    'type_generateur_n1_ecs_n1': 'CET sur air ambiant (sur local non chauffé) après 2014',
#    'numero_voie_ban': '263',
#    'score_ban': 0.49,
#    'conso_chauffage_generateur_n1_installation_n2': 3135.9,
#    'conso_auxiliaires_ep': 705.2,
#    'conso_chauffage_installation_chauffage_n2': 3135.9,
#    'deperditions_murs': 86,
#    'cout_eclairage': 46.5,
#    'conso_auxiliaires_ef': 306.6,
#    'statut_geocodage': "adresse géocodée ban à l'adresse",
#    'ventilation_posterieure_2012': 0,
#    'cout_chauffage': 1506,
#    'conso_5_usages_par_m2_ep': 163,
#    'date_etablissement_dpe': '2022-05-05',
#    'conso_ecs_ef_energie_n1': 560.3,
#    'conso_ecs_ef_energie_n2': 0,
#    'emission_ges_chauffage': 714.3,
#    'description_installation_chauffage_n2': 'Panneau rayonnant électrique NFC, NF** et NF*** avec programmateur pièce par pièce (système individuel)',
#    'description_installation_chauffage_n1': 'Convecteur électrique NFC, NF** et NF*** avec en appoint un poêle à granulés flamme verte installé à partir de 2020 (système individuel)',
#    'description_generateur_chauffage_n2_installation_n1': 'Bois - Poêle à granulés flamme verte installé à partir de 2020',
#    'qualite_isolation_plancher_haut_comble_amenage': 'très bonne',
#    'conso_5_usages_par_m2_ef': 75,
#    'cout_ecs_energie_n2': 0,
#    'conso_chauffage_ef_energie_n1': 8626.6,
#    'conso_chauffage_ef_energie_n2': 1095,
#    'presence_brasseur_air': 0,
#    'qualite_isolation_menuiseries': 'bonne',
#    'cout_total_5_usages_energie_n2': 65.6,
#    'date_reception_dpe': '2022-05-06',
#    'cout_total_5_usages_energie_n1': 1631.6,
#    'cout_ecs_energie_n1': 93.6,
#    'qualite_isolation_plancher_bas': 'insuffisante',
#    'isolation_toiture': 1,
#    'usage_generateur_n2_installation_n1': 'chauffage',
#    'modele_dpe': 'DPE 3CL 2021 méthode logement',
#    'qualite_isolation_enveloppe': 'bonne',
#    'conso_chauffage_generateur_n1_installation_n1': 2309.4,
#    'type_energie_n1': 'Électricité',
#    'emission_ges_eclairage': 19.2,
#    'type_energie_n2': 'Bois – Granulés (pellets) ou briquettes',
#    'code_postal_ban': '85570',
#    'emission_ges_ecs': 36.4,
#    'conso_5_usages_ef_energie_n2': 1095,
#    'conso_5_usages_ef': 10866.9,
#    'conso_5_usages_ef_energie_n1': 9772,
#    'code_insee_ban': '85174',
#    'deperditions_planchers_bas': 46.2,
#    'conso_5_usages_ep': 23570.5,
#    'date_fin_validite_dpe': '2032-05-04',
#    'deperditions_enveloppe': 305.8,
#    'code_region_ban': '52',
#    'type_generateur_n2_installation_n1': 'Poêle à granulés flamme verte installé à partir de 2020',
#    'type_energie_generateur_n2_installation_n1': 'Bois – Granulés (pellets) ou briquettes',
#    'volume_stockage_generateur_n1_ecs_n1': 246,
#    'surface_chauffee_installation_chauffage_n2': 51.6,
#    'surface_chauffee_installation_chauffage_n1': 45.5,
#    'version_dpe': 2.1,
#    'besoin_ecs': 1459.1,
#    'coordonnee_cartographique_x_ban': 400057.98,
#    'type_generateur_chauffage_principal': 'Panneau rayonnant électrique NFC, NF** et NF***',
#    'type_energie_principale_ecs': 'Électricité',
#    'apport_solaire_saison_chauffe': 3282723.7,
#    'adresse_ban': '263 Rue du Chat Ferre 85570 Petosse',
#    'deperditions_renouvellement_air': 107,
#    '_rand': 572937,
#    'surface_habitable_desservie_par_installation_ecs_n1': 144.4,
#    'production_electricite_pv_kwhep_par_an': 0,
#    'nombre_niveau_logement': 2,
#    'surface_habitable_logement': 144.4,
#    'cout_ecs': 93.6,
#    'type_installation_ecs_n1': 'installation individuelle',
#    'emission_ges_5_usages_energie_n1': 756.8,
#    'emission_ges_5_usages_energie_n2': 32.8,
#    'apport_interne_saison_froide': 0,
#    'emission_ges_5_usages_par_m2': 5,
#    'description_generateur_chauffage_n1_installation_n1': 'Electrique - Convecteur électrique NFC, NF** et NF***',
#    'apport_interne_saison_chauffe': 3774914.2,
#    'apport_solaire_saison_froide': 0,
#    'type_generateur_n1_installation_n1': 'Convecteur électrique NFC, NF** et NF***',
#    'nombre_logements_desservis_par_installation_ecs_n1': 1,
#    'type_generateur_n1_installation_n2': 'Panneau rayonnant électrique NFC, NF** et NF***',
#    'cout_auxiliaires': 51.2,
#    'type_emetteur_installation_chauffage_n2': 'Panneau rayonnant NFC, NF** et NF***',
#    'type_emetteur_installation_chauffage_n1': 'Poêle bois',
#    'besoin_chauffage': 10774.7,
#    'configuration_installation_ecs_n1': "Un seul système d'ECS sans solaire",
#    'description_installation_ecs_n1': 'Chauffe-eau thermodynamique sur air ambiant (sur local non chauffé) installé à partir de 2015, contenance ballon 246 L',
#    'description_generateur_chauffage_n1_installation_n2': 'Electrique - Panneau rayonnant électrique NFC, NF** et NF***',
#    'classe_inertie_batiment': 'Moyenne',
#    'deperditions_ponts_thermiques': 25.3,
#    'type_generateur_chauffage_principal_ecs': 'CET sur air ambiant (sur local non chauffé) après 2014',
#    'emission_ges_refroidissement': 0,
#    'hauteur_sous_plafond': 2.5,
#    'conso_chauffage_ef': 9721.5,
#    'nom_commune_ban': 'Petosse',
#    '_geopoint': '46.480643969857184,-0.9113209531387965',
#    'date_visite_diagnostiqueur': '2022-05-05',
#    'type_batiment': 'maison',
#    'periode_construction': 'avant 1948',
#    'conso_ecs_ep': 1288.7,
#    'protection_solaire_exterieure': 0,
#    'conso_ecs_ef': 560.3,
#    'emission_ges_5_usages': 789.6,
#    'date_derniere_modification_dpe': '2024-02-06',
#    'etiquette_ges': 'A',
#    'identifiant_ban': '85174_0048_00263',
#    'deperditions_baies_vitrees': 29.9,
#    'type_energie_generateur_n1_ecs_n1': 'Électricité',
#    'date_installation_generateur_n1_ecs_n1': 'A partir de 2015',
#    'cop_generateur_n1_ecs_n1': 2.8,
#    'ubat_w_par_m2_k': 0.61,
#    'numero_etage_appartement': 0,
#    'nom_commune_brut': 'PETOSSE',
#    'conso_ef_installation_ecs_n1': 560.3,
#    'etiquette_dpe': 'C',
#    'description_generateur_n1_ecs_n1': 'Electrique - Chauffe-eau thermodynamique sur air ambiant (sur local non chauffé) installé à partir de 2015',
#    'code_departement_ban': '85',
#    'type_installation_chauffage_n1': 'installation individuelle',
#    'type_installation_chauffage_n2': 'installation individuelle',
#    'methode_application_dpe': 'dpe maison individuelle',
#    'adresse_brut': '263 rue du Chat Ferré',
#    'logement_traversant': 1,
#    'cout_total_5_usages': 1697.2,
#    'categorie_enr': 'Il existe plusieurs descriptifs ENR',
#    'conso_refroidissement_ef': 0,
#    'conso_eclairage_ef': 278.5,
#    'deperditions_planchers_hauts': 11.6,
#    'zone_climatique': 'H2b',
#    'conso_ef_generateur_n1_ecs_n1': 560.3,
#    'emission_ges_ecs_energie_n1': 36.4,
#    'emission_ges_ecs_energie_n2': 0,
#    'cout_refroidissement': 0,
#    'conso_chauffage_ep': 20936.1,
#    'usage_generateur_n1_installation_n2': 'chauffage',
#    'conso_eclairage_ep': 640.5,
#    'usage_generateur_n1_installation_n1': 'chauffage',
#    'nom_rue_ban': 'Rue du Chat Ferre',
#    'qualite_isolation_murs': 'insuffisante',
#    'type_installation_solaire_n1': 'Non affecté',
#    'classe_altitude': 'inférieur à 400m',
#    'conso_refroidissement_ep': 0,
#    'type_energie_principale_chauffage': 'Électricité',
#    'numero_dpe': '2285E0980644K',
#    '_i': 1362404395025,
#    'besoin_refroidissement': 0,
#    'emission_ges_chauffage_energie_n2': 32.8,
#    'indicateur_confort_ete': 'insuffisant',
#    'emission_ges_chauffage_energie_n1': 681.5,
#    'inertie_lourde': 0,
#    'cout_chauffage_energie_n2': 65.6,
#    'deperditions_portes': 0,
#    'cout_chauffage_energie_n1': 1440.4,
#    'conso_chauffage_generateur_n2_installation_n1': 1095,
#    'type_energie_generateur_n1_installation_n2': 'Électricité',
#    'coordonnee_cartographique_y_ban': 6605280.58,
#    'type_energie_generateur_n1_installation_n1': 'Électricité',
#    'code_postal_brut': 85570,
#    'emission_ges_auxiliaires': 19.6,
#    'usage_generateur_n1_ecs_n1': 'ecs',
#    '_score': None,
#    '_id': 'b90cde4467575dea796d63686eeedf34719293ac3cb9131a87abfd77f4ef43b9'}]}

# %% [markdown]
# Effectuer une requête GET en récupérant les données de la page 1 avec 5 résultats

# %%
params = {
    'page': 1,
    'size': 5,
    'select': 'numero_dpe,etiquette_dpe,date_reception_dpe'
}

quick_requests(params)
# Out:
# {'total': 12867611,
#  'next': 'https://data.ademe.fr/data-fair/api/v1/datasets/meg-83tjwtg8dyz4vv7h1dqe/lines?size=5&select=numero_dpe%2Cetiquette_dpe%2Cdate_reception_dpe&after=1362404395012%2C361733',
#  'results': [{'numero_dpe': '2275E0252200Y',
#    'date_reception_dpe': '2022-02-08',
#    'etiquette_dpe': 'D',
#    '_score': None},
#   {'numero_dpe': '2254E0866216D',
#    'date_reception_dpe': '2022-04-25',
#    'etiquette_dpe': 'E',
#    '_score': None},
#   {'numero_dpe': '2275E1242094U',
#    'date_reception_dpe': '2022-06-07',
#    'etiquette_dpe': 'D',
#    '_score': None},
#   {'numero_dpe': '2244E1489464V',
#    'date_reception_dpe': '2022-06-30',
#    'etiquette_dpe': 'D',
#    '_score': None},
#   {'numero_dpe': '2293E0210795D',
#    'date_reception_dpe': '2022-02-02',
#    'etiquette_dpe': 'D',
#    '_score': None}]}

# %% [markdown]
# Effectuer une requête GET en récupérant les données de la page 1 avec 5 résultats et en sélectionnant les colonnes N°DPE, Etiquette_DPE et Date_réception_DPE et en filtrant par Etiquette_DPE égale à E

# %%
params = {
    'page': 1,
    'size': 5,
    'select': 'numero_dpe,etiquette_dpe,date_reception_dpe',
    'q_fields': 'etiquette_dpe',
    'q': 'E'
}

quick_requests(params)
# Out:
# {'total': 2487267,
#  'next': 'https://data.ademe.fr/data-fair/api/v1/datasets/meg-83tjwtg8dyz4vv7h1dqe/lines?size=5&select=numero_dpe%2Cetiquette_dpe%2Cdate_reception_dpe&q_fields=etiquette_dpe&q=E&after=5.54806%2C1362404395028%2C24677',
#  'results': [{'numero_dpe': '2254E0866216D',
#    'date_reception_dpe': '2022-04-25',
#    'etiquette_dpe': 'E',
#    '_score': 5.54806},
#   {'numero_dpe': '2289E0379633T',
#    'date_reception_dpe': '2022-02-25',
#    'etiquette_dpe': 'E',
#    '_score': 5.54806},
#   {'numero_dpe': '2256E0388464D',
#    'date_reception_dpe': '2022-02-25',
#    'etiquette_dpe': 'E',
#    '_score': 5.54806},
#   {'numero_dpe': '2268E1169752D',
#    'date_reception_dpe': '2022-05-29',
#    'etiquette_dpe': 'E',
#    '_score': 5.54806},
#   {'numero_dpe': '2202E1104459I',
#    'date_reception_dpe': '2022-05-19',
#    'etiquette_dpe': 'E',
#    '_score': 5.54806}]}

# %% [markdown]
# Effectuer une requête GET en récupérant les données de la page 1 avec 20 résultats et en sélectionnant les colonnes N°DPE, Etiquette_DPE et Date_réception_DPE et en filtrant par Etiquette_DPE égale à E, F ou G.

# %%
params = {
    'page': 1,
    'size': 5,
    'select': 'numero_dpe,etiquette_dpe,date_reception_dpe',
    'q_fields': 'etiquette_dpe',
    'q': 'E,F,G'
}

quick_requests(params)
# Out:
# {'total': 4116790,
#  'next': 'https://data.ademe.fr/data-fair/api/v1/datasets/meg-83tjwtg8dyz4vv7h1dqe/lines?size=5&select=numero_dpe%2Cetiquette_dpe%2Cdate_reception_dpe&q_fields=etiquette_dpe&q=E%2CF%2CG&after=7.8537674%2C1362404395262%2C749176',
#  'results': [{'numero_dpe': '2263E0767291R',
#    'date_reception_dpe': '2022-04-12',
#    'etiquette_dpe': 'G',
#    '_score': 7.8537674},
#   {'numero_dpe': '2222E0682673O',
#    'date_reception_dpe': '2022-04-02',
#    'etiquette_dpe': 'G',
#    '_score': 7.8537674},
#   {'numero_dpe': '2272E0353529C',
#    'date_reception_dpe': '2022-02-22',
#    'etiquette_dpe': 'G',
#    '_score': 7.8537674},
#   {'numero_dpe': '2261E0066009F',
#    'date_reception_dpe': '2022-01-13',
#    'etiquette_dpe': 'G',
#    '_score': 7.8537674},
#   {'numero_dpe': '2273E0251590K',
#    'date_reception_dpe': '2022-02-08',
#    'etiquette_dpe': 'G',
#    '_score': 7.8537674}]}

# %% [markdown]
# Effectuer une requête GET en récupérant les données de la page 1 avec 5 résultats et en sélectionnant les colonnes N°DPE, Etiquette_DPE et Date_réception_DPE et en filtrant par Date_réception_DPE entre le 2024-01-01 au 2024-01-31

# %%
params = {
    'page': 1,
    'size': 5,
    'select': 'numero_dpe,etiquette_dpe,date_reception_dpe',
    'qs': 'date_reception_dpe:[2024-01-01 TO 2024-01-31]'
}

quick_requests(params)
# Out:
# {'total': 320979,
#  'next': 'https://data.ademe.fr/data-fair/api/v1/datasets/meg-83tjwtg8dyz4vv7h1dqe/lines?size=5&select=numero_dpe%2Cetiquette_dpe%2Cdate_reception_dpe&qs=date_reception_dpe%3A%5B2024-01-01+TO+2024-01-31%5D&after=3741286580090%2C834008',
#  'results': [{'numero_dpe': '2465E0137289Z',
#    'date_reception_dpe': '2024-01-14',
#    'etiquette_dpe': 'C',
#    '_score': None},
#   {'numero_dpe': '2459E0264861J',
#    'date_reception_dpe': '2024-01-24',
#    'etiquette_dpe': 'D',
#    '_score': None},
#   {'numero_dpe': '2493E0115701T',
#    'date_reception_dpe': '2024-01-11',
#    'etiquette_dpe': 'G',
#    '_score': None},
#   {'numero_dpe': '2469E0344404C',
#    'date_reception_dpe': '2024-01-30',
#    'etiquette_dpe': 'D',
#    '_score': None},
#   {'numero_dpe': '2440E0346728J',
#    'date_reception_dpe': '2024-01-30',
#    'etiquette_dpe': 'C',
#    '_score': None}]}

# %% [markdown]
# Effectuer une requête GET en récupérant les données de la page 1 avec 5 résultats et en sélectionnant les colonnes N°DPE, Etiquette_DPE et Date_réception_DPE et en filtrant par Date_réception_DPE après le 2024-07-31

# %%
params = {
    'page': 1,
    'size': 5,
    'select': 'numero_dpe,etiquette_dpe,date_reception_dpe',
    'qs': 'date_reception_dpe:[2024-07-31 TO *]'
}

quick_requests(params)
# Out:
# {'total': 3894930,
#  'next': 'https://data.ademe.fr/data-fair/api/v1/datasets/meg-83tjwtg8dyz4vv7h1dqe/lines?size=5&select=numero_dpe%2Cetiquette_dpe%2Cdate_reception_dpe&qs=date_reception_dpe%3A%5B2024-07-31+TO+*%5D&after=7770079089006%2C824425',
#  'results': [{'numero_dpe': '2477E4416759L',
#    'date_reception_dpe': '2024-12-12',
#    'etiquette_dpe': 'B',
#    '_score': None},
#   {'numero_dpe': '2457E3676767L',
#    'date_reception_dpe': '2024-10-18',
#    'etiquette_dpe': 'C',
#    '_score': None},
#   {'numero_dpe': '2592E0857815P',
#    'date_reception_dpe': '2025-03-13',
#    'etiquette_dpe': 'D',
#    '_score': None},
#   {'numero_dpe': '2456E3827496R',
#    'date_reception_dpe': '2024-10-30',
#    'etiquette_dpe': 'D',
#    '_score': None},
#   {'numero_dpe': '2440E4239301S',
#    'date_reception_dpe': '2024-11-29',
#    'etiquette_dpe': 'E',
#    '_score': None}]}

# %% [markdown]
# Effectuer une requête GET en récupérant les données de la page 1 avec 5 résultats et en sélectionnant les colonnes N°DPE, Etiquette_DPE, Date_réception_DPE et Code_postal_(BAN) en filtrant par le Code_postal_(BAN) 69360. Combien y a t-il de logements concernés dans la base de données ?

# %%
params = {
    'page': 1,
    'size': 5,
    'select': 'numero_dpe,etiquette_dpe,date_reception_dpe,code_postal_ban',
    'q_fields': 'code_postal_ban',
    'q': '69360'
}

quick_requests(params)
# Out:
# {'total': 2828,
#  'next': 'https://data.ademe.fr/data-fair/api/v1/datasets/meg-83tjwtg8dyz4vv7h1dqe/lines?size=5&select=numero_dpe%2Cetiquette_dpe%2Cdate_reception_dpe%2Ccode_postal_ban&q_fields=code_postal_ban&q=69360&after=33.731533%2C1362525211737%2C545369',
#  'results': [{'numero_dpe': '2269E1399563B',
#    'date_reception_dpe': '2022-06-22',
#    'code_postal_ban': '69360',
#    'etiquette_dpe': 'C',
#    '_score': 33.731533},
#   {'numero_dpe': '2269E0041218A',
#    'date_reception_dpe': '2022-01-10',
#    'code_postal_ban': '69360',
#    'etiquette_dpe': 'D',
#    '_score': 33.731533},
#   {'numero_dpe': '2269E0499359V',
#    'date_reception_dpe': '2022-03-12',
#    'code_postal_ban': '69360',
#    'etiquette_dpe': 'C',
#    '_score': 33.731533},
#   {'numero_dpe': '2269E1447584A',
#    'date_reception_dpe': '2022-06-27',
#    'code_postal_ban': '69360',
#    'etiquette_dpe': 'F',
#    '_score': 33.731533},
#   {'numero_dpe': '2269E1404078S',
#    'date_reception_dpe': '2022-06-22',
#    'code_postal_ban': '69360',
#    'etiquette_dpe': 'D',
#    '_score': 33.731533}]}

# %% [markdown]
# ## Extraction des données complètes pour le Rhône

# %% [markdown]
# Setup cwd

# %%
import os

os.chdir('/Users/marinnagy/Documents/SISE/Python ML/Chapitre 2')

# %% [markdown]
# Récupérer tous les codes postaux du département du Rhône(69) à l'aide du fichier `adresses-69.csv`

# %%
import pandas as pd

adresses = pd.read_csv('resources/adresses-69.csv', sep=';', low_memory=False)
adresses.shape
# Out:
# (348195, 23)

# %% [markdown]
# Avec une boucle, parcourir chaque code postal afin de reconstruire le dataframe complet des logements existants sur le département. Exporter le résultat dans un fichier appelé `existants_69.csv`

# %% [markdown]
# Fonction de requette a l'API

# %%
import time

def requests_API(params:dict = None, custom_url:str = None, tic:int = 0) -> dict:

    try:

        if custom_url:
            response = requests.get(custom_url)
        else:
            response = requests.get(root_url, params=params)

    except ConnectionError:

        print(f'ConnectionError, network failed to request API ({tic+1}/3)')

        if(tic == 3):
            print('Failed to fetch')
            return None
        
        print('Trying again in 1 second')
        time.sleep(1)
        return requests_API(params=params, custom_url=custom_url, tic=tic+1)
        
    if response.status_code != 200:
        print(response.text)
        return None
    
    return response.json()

# %% [markdown]
# Fonction d'ajoutt de donnée au dataframe

# %%
def append_data(df:pd.DataFrame, data:list[dict]) -> None:
    
    data_df = pd.DataFrame(data)
    return pd.concat([df, data_df], ignore_index=True)

# %% [markdown]
# ```python
# from datetime import datetime
#
# existants = pd.DataFrame()
#
# for code_postal in adresses['code_postal'].unique():
#
#     params = {
#         'q_fields': 'code_postal_ban',
#         'q': code_postal,
#         'size': 0
#     }
#
#     # requests the count of results
#     response = requests_API(params)
#     print(f'Gettting {code_postal} ({response[0]} items)')
#
#     # if more than 1000 results, split the requests into months
#     if response[0] > 10000:
#         for year in range(2021, datetime.now().year+1):
#             print(f'   {year}', end=' ', flush=True)
#             for month in range(1, 12+1):
#                 print(month, end='..')
#                 params['size'] = 10000
#                 params['qs'] = f'date_visite_diagnostiqueur:[{year}-{month:02}-01 TO {year}-{month:02}-31]'
#                 response = requests_API(params)
#                 existants = append_data(existants, response[1])
#             print()
#         continue
#
#     params['size'] = 10000
#     response = requests_API(params)
#     existants = append_data(existants, response[1])
# ```

# %% [markdown]
# ```python
# import time
#
# for code_postal in ['69100']:
#
#     # first, get the total count
#     base_params = {
#         'q_fields': 'code_postal_ban',
#         'q': code_postal,
#         'size': 0
#     }
#     resp = requests_API(base_params)
#     if resp is None:
#         continue
#     total = resp[0]
#     print(f'Getting {code_postal} ({total} items)')
#
#     # if more than 10000 results, split requests by month and fetch months concurrently
#     if total > 10000:
#         for year in range(2021, datetime.now().year + 1):
#             print(f'   {year}', end=' ', flush=True)
#
#             # build the 12 monthly requests
#             reqs = []
#             for month in range(1, 13):
#                 params_month = {
#                     'q_fields': 'code_postal_ban',
#                     'q': code_postal,
#                     'size': 10000,
#                     'qs': f'date_visite_diagnostiqueur:[{year}-{month:02}-01 TO {year}-{month:02}-31]'
#                 }
#                 reqs.append(grequests.get(root_url, params=params_month))
#
#             # fire all 12 at once and wait
#             responses = grequests.map(reqs, size=12)
#
#             # collect results
#             for r in responses:
#                 if not r:
#                     print('Hmm NULL')
#                 elif r.status_code != 200:
#                     print(f'Hoho, code {r.stattus_code}')
#                     print(r.text)
#                 content = r.json()
#                 existants = append_data(existants, content.get('results', []))
#             print(existants.shape)  # newline for the year block
#             time.sleep(1)
#
#         continue
#
#     # otherwise, single shot (<= 10000)
#     params = {
#         'q_fields': 'code_postal_ban',
#         'q': code_postal,
#         'size': 10000
#     }
#     resp = requests_API(params)
#     if resp is not None:
#         existants = append_data(existants, resp[1])
# ```

# %% [markdown]
# Il est possible de passer outre la limitation de requette de l'API `size * page < 10000` en utilisant l'argument `after` au lieu de `page`. Un lien pre-construit utilisant cette argument est fourni dans la reponse sous la clef `next` du json.

# %%
def get_all_data() -> pd.DataFrame:

    df = pd.DataFrame()

    for code_postal in adresses['code_postal'].unique():
        
        # requests the count of results

        params = {
            'q_fields': 'code_postal_ban',
            'q': code_postal,
            'size': 0
        }

        response = requests_API(params=params)
        _total = response['total']
        print(f'{code_postal} ({_total} items)', end=' -> ', flush=True)

        # init for the requests

        params['size'] = 10000
        print('1', end=' ... ', flush=True)
        response = requests_API(params=params)
        df = append_data(df, response['results'])

        # loop through the results

        index = 2
        while 'next' in response.keys():
            print(index, end=' ... ', flush=True)
            response = requests_API(None, custom_url=response['next'])
            df = append_data(df, response['results'])
            index += 1

        print('done')

    return df

# %%
root_url = 'https://data.ademe.fr/data-fair/api/v1/datasets/dpe03existant/lines'
existants = get_all_data()
existants.to_csv('existants_69.csv')

# %% [markdown]
# Même chose pour les logements neufs

# %%
root_url = 'https://data.ademe.fr/data-fair/api/v1/datasets/dpe02neuf/lines'
neufs = get_all_data()
neufs.to_csv('neufs_69.csv')
# Out:
# 69790 (1 items) ... 1 ... done
# 69170 (232 items) ... 1 ... done
# 69250 (480 items) ... 1 ... done
# 69380 (556 items) ... 1 ... done
# 69009 (1363 items) ... 1 ... done
# 69008 (3041 items) ... 1 ... done
# 69006 (323 items) ... 1 ... done
# 69007 (2349 items) ... 1 ... done
# 69005 (414 items) ... 1 ... done
# 69001 (44 items) ... 1 ... done
# 69004 (207 items) ... 1 ... done
# 69002 (378 items) ... 1 ... done
# 69003 (1015 items) ... 1 ... done
# 69780 (353 items) ... 1 ... done
# 69360 (512 items) ... 1 ... done
# 69124 (91 items) ... 1 ... done
# 69580 (286 items) ... 1 ... done
# 69720 (419 items) ... 1 ... done
# 69960 (254 items) ... 1 ... done
# 69320 (204 items) ... 1 ... done
# 69800 (1141 items) ... 1 ... done
# 69140 (874 items) ... 1 ... done
# 69330 (370 items) ... 1 ... done
# 69970 (268 items) ... 1 ... done
# 69730 (45 items) ... 1 ... done
# 69740 (206 items) ... 1 ... done
# 69150 (669 items) ... 1 ... done
# 69680 (217 items) ... 1 ... done
# 69510 (354 items) ... 1 ... done
# 69390 (309 items) ... 1 ... done
# 69910 (18 items) ... 1 ... done
# 69100 (3776 items) ... 1 ... done
# 69640 (61 items) ... 1 ... done
# 69770 (27 items) ... 1 ... done
# 69400 (2100 items) ... 1 ... done
# 69430 (57 items) ... 1 ... done
# 69820 (32 items) ... 1 ... done
# 69460 (65 items) ... 1 ... done
# 69200 (1826 items) ... 1 ... done
# 69120 (1791 items) ... 1 ... done
# 69420 (190 items) ... 1 ... done
# 69670 (156 items) ... 1 ... done
# 69890 (145 items) ... 1 ... done
# 69620 (99 items) ... 1 ... done
# 69240 (8 items) ... 1 ... done
# 69160 (618 items) ... 1 ... done
# 69220 (227 items) ... 1 ... done
# 69440 (256 items) ... 1 ... done
# 69490 (202 items) ... 1 ... done
# 69700 (707 items) ... 1 ... done
# 69560 (114 items) ... 1 ... done
# 69590 (50 items) ... 1 ... done
# 69270 (288 items) ... 1 ... done
# 69870 (25 items) ... 1 ... done
# 69210 (462 items) ... 1 ... done
# 69850 (103 items) ... 1 ... done
# 69930 (34 items) ... 1 ... done
# 69690 (14 items) ... 1 ... done
# 69550 (69 items) ... 1 ... done
# 69650 (250 items) ... 1 ... done
# 69830 (167 items) ... 1 ... done
# 69290 (604 items) ... 1 ... done
# 69230 (66 items) ... 1 ... done
# 69610 (78 items) ... 1 ... done
# 69110 (415 items) ... 1 ... done
# 69190 (278 items) ... 1 ... done
# 69450 (328 items) ... 1 ... done
# 69370 (149 items) ... 1 ... done
# 69280 (138 items) ... 1 ... done
# 69470 (8 items) ... 1 ... done
# 69480 (329 items) ... 1 ... done
# 69530 (634 items) ... 1 ... done
# 69310 (177 items) ... 1 ... done
# 69600 (147 items) ... 1 ... done
# 69350 (1 items) ... 1 ... done
# 69860 (11 items) ... 1 ... done
# 69760 (162 items) ... 1 ... done
# 69840 (18 items) ... 1 ... done
# 69540 (459 items) ... 1 ... done
# 69520 (177 items) ... 1 ... done
# 69340 (516 items) ... 1 ... done
# 69130 (189 items) ... 1 ... done
# 69570 (231 items) ... 1 ... done
# 69660 (370 items) ... 1 ... done
# 69115 (8 items) ... 1 ... done
# 69260 (166 items) ... 1 ... done
# 69410 (344 items) ... 1 ... done
# 69630 (256 items) ... 1 ... done
# 69300 (670 items) ... 1 ... done
# 69500 (1559 items) ... 1 ... done
# 69126 (106 items) ... 1 ... done
# Completed

# %% [markdown]
# Fusionner les deux dataframes avec uniquement les colonnes communes.

# %%
logements = pd.concat([existants, neufs], join="inner")
logements.shape

# %% [markdown]
# Exporter le résultat en dans un fichie appelé logements_69.csv

# %%
logements.to_csv('logements_69.csv')

# %% [markdown]
# ## Extraction des données d'ENEDIS de consommation par adresse

# %% [markdown]
# Extraire l'ensemble des données de la region lyonnaise (69)

# %%
root_url = 'https://data.enedis.fr/api/explore/v2.1/catalog/datasets/consommation-annuelle-residentielle-par-adresse/records'

params = {
    'refine': 'code_departement:69',
    'limit': 1
}

response = requests_API(params=params)
response['total_count']
# Out:
# 165267

# %% [markdown]
# Nous devons extraire 165267 logements, or l'API nous limits au 10000 premiers resultats d'une recherche. On peut donc essayer de séparer nos recherche par code de communes

# %%
params = {
    'select': 'count(code_commune) as count, code_commune',
    'refine': 'code_departement:69',
    'group_by': 'code_commune',
    'order_by': 'count DESC',
    'limit': 10
}

response = requests_API(params=params)

print(response['total_count'])
for commune in response['results']:
    print(commune['code_commune'], commune['count'])
# Out:
# 170
# 69123 78963
# 69266 19834
# 69259 6553
# 69264 4439
# 69034 4412
# 69029 3961
# 69290 3960
# 69256 3270
# 69286 2924
# 69149 2892

# %% [markdown]
# Nous avons 170 communes, mais 2 d'entre elles comportent plus de 10000 logements (69123 et 69266)... Lyon et Villeurbanne nous posent soucie ici. Il nous faut prévoir une condition dans notre boucle pour que les requettes sur ces communes soient découpées en plusieur requette. Essayons de voir si diviser la requette par `code_iris` peut faire l'affaire

# %%
params = {
    'select': 'count(*) as count',
    'group_by': 'code_iris',
    'order_by': 'count DESC',
    'limit': 1
}

for code_commune in [69123, 69266]:
    params['refine'] = f'code_commune:{code_commune}'
    response = requests_API(params=params)
    print(response['results'][0]['count'])
# Out:
# 1471
# 1050

# %% [markdown]
# Top! Nous avons moins de 10000 logements pour chacune des requettes! Voyons maintenant comment recolter l'entiereté du dataset de l'API. Nous pouvons d'abord construire une fonction qui nous permettera de faire des appelels a d'API page par page pour une requette

# %%
def loop_API(params, limit=100):

    results = []

    stop = False
    index = 0
    while not stop:

        params['limit'] = limit
        params['offset'] = limit * index
        response = requests_API(params=params)

        # stop the loop if last page
        if len(response['results']) < limit:
            stop = True

        results.extend(response['results'])

        # increase index
        index += 1

    return results

# %% [markdown]
# Recoltons d'abords la liste des code de communes a parser ainsi que leur nombre de logements

# %%
params = {
    'select': 'count(code_commune) as count, code_commune',
    'refine': 'code_departement:69',
    'group_by': 'code_commune'
}

communes = loop_API(params)

# %% [markdown]
# Nous pouvons maintenant construire une boucle pour collecter l'ensemble des logement de ces communes

# %%
enedis_69 = pd.DataFrame()

for commune in communes:

    code = commune['code_commune']
    count = commune['count']
    print(code, count, end=" ... ")

    if count > 10000:

        params = {
            'select': 'count(*) as count, code_iris',
            'refine': f'code_commune:{code}',
            'group_by': 'code_iris'
        }

        codes_iris = loop_API(params)
        for i, data_iris in enumerate(codes_iris):
            
            iris = data_iris['code_iris']
            params = {
                'refine': [
                    f'code_commune:{code}',
                    f'code_iris:{iris}'
                ]
            }

            data = loop_API(params)
            enedis_69 = append_data(enedis_69, data)

    else:

        params = {
            'refine': f'code_commune:{code}'
        }

        data = loop_API(params)
        enedis_69 = append_data(enedis_69, data)

    print('done')
# Out:
# 69003 77 ... done
# 69006 100 ... done
# 69007 29 ... done
# 69009 238 ... done
# 69010 413 ... done
# 69013 110 ... done
# 69018 13 ... done
# 69019 639 ... done
# 69020 5 ... done
# 69021 6 ... done
# 69023 11 ... done
# 69024 20 ... done
# 69027 898 ... done
# 69028 222 ... done
# 69029 3961 ... done
# 69031 22 ... done
# 69032 15 ... done
# 69033 73 ... done
# 69034 4412 ... done
# 69036 1 ... done
# 69040 478 ... done
# 69043 331 ... done
# 69044 297 ... done
# 69045 1 ... done
# 69046 72 ... done
# 69049 47 ... done
# 69050 7 ... done
# 69052 76 ... done
# 69055 36 ... done
# 69056 7 ... done
# 69057 7 ... done
# 69059 11 ... done
# 69061 2 ... done
# 69063 220 ... done
# 69064 208 ... done
# 69066 26 ... done
# 69067 6 ... done
# 69068 81 ... done
# 69069 706 ... done
# 69071 27 ... done
# 69072 221 ... done
# 69074 3 ... done
# 69076 66 ... done
# 69080 21 ... done
# 69081 1315 ... done
# 69082 1 ... done
# 69085 41 ... done
# 69086 54 ... done
# 69087 73 ... done
# 69088 733 ... done
# 69089 838 ... done
# 69090 1 ... done
# 69091 1408 ... done
# 69092 457 ... done
# 69094 237 ... done
# 69096 470 ... done
# 69100 493 ... done
# 69105 8 ... done
# 69106 9 ... done
# 69108 7 ... done
# 69109 3 ... done
# 69110 1 ... done
# 69111 1 ... done
# 69112 155 ... done
# 69113 2 ... done
# 69115 248 ... done
# 69116 118 ... done
# 69117 65 ... done
# 69118 28 ... done
# 69121 125 ... done
# 69122 30 ... done
# 69123 78963 ... done
# 69125 7 ... done
# 69126 3 ... done
# 69127 101 ... done
# 69131 74 ... done
# 69133 138 ... done
# 69136 35 ... done
# 69140 35 ... done
# 69141 252 ... done
# 69142 784 ... done
# 69143 538 ... done
# 69145 12 ... done
# 69148 54 ... done
# 69149 2892 ... done
# 69151 7 ... done
# 69153 5 ... done
# 69154 95 ... done
# 69156 24 ... done
# 69157 52 ... done
# 69159 25 ... done
# 69163 50 ... done
# 69168 40 ... done
# 69170 6 ... done
# 69171 73 ... done
# 69172 5 ... done
# 69175 7 ... done
# 69176 54 ... done
# 69177 1 ... done
# 69178 7 ... done
# 69179 23 ... done
# 69189 177 ... done
# 69190 47 ... done
# 69191 225 ... done
# 69194 300 ... done
# 69197 11 ... done
# 69199 1479 ... done
# 69200 9 ... done
# 69201 50 ... done
# 69202 2248 ... done
# 69204 986 ... done
# 69205 103 ... done
# 69206 101 ... done
# 69207 126 ... done
# 69208 7 ... done
# 69212 14 ... done
# 69214 14 ... done
# 69219 31 ... done
# 69220 19 ... done
# 69227 74 ... done
# 69228 31 ... done
# 69231 45 ... done
# 69233 14 ... done
# 69235 52 ... done
# 69238 102 ... done
# 69241 36 ... done
# 69243 432 ... done
# 69244 2197 ... done
# 69245 2 ... done
# 69248 56 ... done
# 69249 52 ... done
# 69250 144 ... done
# 69254 5 ... done
# 69255 158 ... done
# 69256 3270 ... done
# 69259 6553 ... done
# 69260 205 ... done
# 69264 4439 ... done
# 69266 19834 ... done
# 69267 13 ... done
# 69268 82 ... done
# 69269 7 ... done
# 69270 83 ... done
# 69271 404 ... done
# 69272 74 ... done
# 69273 574 ... done
# 69275 2645 ... done
# 69276 482 ... done
# 69277 367 ... done
# 69278 207 ... done
# 69279 72 ... done
# 69281 23 ... done
# 69282 2091 ... done
# 69283 480 ... done
# 69284 55 ... done
# 69285 42 ... done
# 69286 2924 ... done
# 69287 126 ... done
# 69288 143 ... done
# 69289 45 ... done
# 69290 3960 ... done
# 69291 126 ... done
# 69292 673 ... done
# 69293 30 ... done
# 69294 132 ... done
# 69295 54 ... done
# 69296 65 ... done
# 69297 75 ... done
# 69298 52 ... done
# 69299 8 ... done

# %% [markdown]
# Sauvegarder le dataframe en CSV

# %%
enedis_69.shape
enedis_69.to_csv('enedis_69.csv')
